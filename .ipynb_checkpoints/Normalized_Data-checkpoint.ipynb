# %%
# !pip install conllu

org_to_norm = {}

import conllu

def parse_conllu_file1(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.read()

    # Parse the CoNLL-U formatted data
    parsed_data = conllu.parse(data)

    # Extract tokens, lines, and folios
    tokens_info = []
    for sentence in parsed_data:
        for token in sentence:
            try:
                if 'misc' in token:
                    if "Norm" in token['misc']:
                        if "Orig" in token['misc']:
                            x = token['misc']['Orig']
                            if x not in org_to_norm:
                                org_to_norm[x] = ""


                        else:
                            x = token["form"]
                            if x not in org_to_norm:
                                org_to_norm[x] = ""
            except:
                continue
            
            
    return org_to_norm

def parse_conllu_file2(file_path):
    
    with open(file_path, 'r', encoding='utf-8') as file:
        data = file.read()

    # Parse the CoNLL-U formatted data
    parsed_data = conllu.parse(data)

    # Extract tokens, lines, and folios
    tokens_info = []
    for sentence in parsed_data:
        for token in sentence:
            try:
                if "misc" in token:
                    if "Norm" in token['misc']:
                        if "Orig" in token['misc']:
                            x = token['misc']['Orig']
                            y = token['misc']['Norm']
                            if y not in org_to_norm[x]:
                                org_to_norm[x]+=y+"#"
                                


                        else:
                            x = token["form"]
                            y = token['misc']['Norm']
                            if y not in org_to_norm[x]:
                                org_to_norm[x]+=y+"#"
                                
            except:
                continue

# Example usage
file_path = "book5.conllu"
parse_conllu_file1(file_path)
parse_conllu_file2(file_path)



for k in org_to_norm:
    org_to_norm[k] = org_to_norm[k][:-1]
    
    if "¶" in k:
        i = k.index("¶")
        t = []
        
        for c in org_to_norm[k]:
            t.append(c)
        
        hash_count = t[:i+1].count("#")
        
        t.insert(i+hash_count,"¶")
        org_to_norm[k] = "".join(t)

org_to_norm_final = {}

for k in org_to_norm:
    key = k
    
    if "¶·" in key:
        key = key.replace("¶·","¶")
    
    if "·" in key and "¶·" not in key:
        key = key.replace("·","#")
        
    
    if key[-1] == "¶" and len(key)>1:
        key = key[:-1]
        x = list(org_to_norm[k])
        x.remove("¶")
        value = "".join(x)
        org_to_norm_final[key] = value
    org_to_norm_final[key] = org_to_norm[k]


            
            
# Print the extracted information

# %%
# Run on colab
paragraph_data = {
    '3': [(0,2),(3,9),(10,20),(21,28)],
    '4':[(0,31)],
    '5':[(0,14),(15,21),(22,30)],
    '6':[(0,28)],
    '7':[(0,26)],
    '8':[(0,27)],
    '9': [(0,27)],
    '10': [(0,5),(6,11),(12,24)],
    '11': [(0,25)],
    '12': [(0,25)],
    '13':[(0,26)],
    '14': [(0,12),(13,15),(16,23)],
    '15': [(0,23)],
    '16': [(0,2),(3,28)],
    '17': [(0,6),(7,10),(11,27)],
    '18': [(0,2),(3,6),(7,16),(17,19),(20,28)],
    '19': [(0,26)],
    '20': [(0,2),(3,8),(9,28)],
    '21': [(0,8),(9,12),(13,26)],
    '22': [(0,21),(22,25)],
    '23': [(0,11),(12,26)],
    '24': [(0,8),(9,12),(13,25)],
    '25': [(0,25)],
    '26': [(0,9),(10,12),(13,24)],
    '27': [(0,16),(17,24)],
    '28': [(0,7),(8,24)]
}
key = 28
import pickle

# %%
ref_map

# %%
import pickle
with open(f'ref_map_org.pkl', 'rb') as pickle_file:
        ref_map = pickle.load(pickle_file)
        
import pickle
with open(f'ref_map_norm.pkl', 'rb') as pickle_file:
        norm_map = pickle.load(pickle_file)
    
    
ref_map2 = {}
norm_map2 = {}



for k in range(3,29):
    ref_map2[k] = []
    
for k in range(3,29):
    norm_map2[k] = []

for k in range(3,29):
    for i in range(len(ref_map[k])-1):
        x1 = ref_map[k][i]
        x2 = ref_map[k][i+1]
        
        if not x2[0].isupper():
            x1 = x1 + '-'
        
        ref_map2[k].append(x1)
    ref_map2[k].append(x2)
        
for k in range(3,29):
    for i in range(len(norm_map[k])-1):
        x1 = norm_map[k][i]
        x2 = norm_map[k][i+1]
        
        if not x2[0].isupper():
            x1 = x1 + '-'
        
        norm_map2[k].append(x1)
        
    norm_map2[k].append(x2)

# %%
def get_tokens_from_conllu_file(file_path):
    orig_tokens = []
    norm_tokens = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if line and not line.startswith('#'):  # Skip empty lines and metadata lines
                fields = line.split('\t')
                if len(fields) >= 2:  # Ensure it's a valid token line
                    print(fields)
                    token1 = fields[1]
                    token2 = fields[2]
                    orig_tokens.append(token1)
                    norm_tokens.append(token2)
    return orig_tokens, norm_tokens


# Example usage:
conllu_file_path = 'file.conllu'  # Replace 'example.conllu' with your file path
orig_tokens, norm_tokens = get_tokens_from_conllu_file(conllu_file_path)
#print(all_tokens)
# Out:
# ['1', 'Jc', 'ic', 'ADV', '_', '_', '3', 'amod', '3:amod', 'Folio=1r|Paragraph=1|Line=1|Norm=Ic']
# ['2', 'macujlli', 'macuilli', 'NUM', '_', '_', '1', 'nummod', '1:nummod', 'Folio=1r|Paragraph=1|Line=1|Norm=macuilli|Gloss=cinco']
# ['3', 'amuxtli', 'amoxtli', 'NOUN', '_', 'State=Abs', '6', 'obl', '6:obl', 'Folio=1r|Paragraph=1|Line=1|Norm=amoxtli|Gloss=libro|Analysed=Yes']
# ['4', ',', ',', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=1r|Paragraph=1|Line=1|Norm=,|Analysed=Yes']
# ['5', 'vncan', 'oncan', 'ADV', '_', '', '6', 'advmod', '6:advmod', 'Folio=1r|Paragraph=1|Line=1|Norm=oncan|Gloss=aquí|Analysed=Yes']
# ['6', 'moteneoa', 'tenehua', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Reflex[obj]=Yes|Subcat=Tran|Tense=Pres|VerbForm=Fin', '0', 'root', '0:root', 'Orig=mo¶·teneoa|Folio=1r,1r|Paragraph=1,1|Line=1,2|Norm=motenehua|Analysed=Yes']
# ['7', ':', ':', 'PUNCT', '_', '', '9', 'punct', '9:punct', 'Folio=1r|Paragraph=1|Line=2|Norm=:|Analysed=Yes']
# ['8', 'in', 'in', 'SCONJ', '_', '_', '9', 'mark', '9:mark', 'Orig=intetzaujtl|Folio=1r|Paragraph=1|Line=2|Norm=in']
# ['9', 'tetzaujtl', 'tetzahuitl', 'NOUN', '_', 'State=Abs', '6', 'csubj', '6:csubj', 'Orig=intetzaujtl|Folio=1r|Paragraph=1|Line=2|Norm=tetzahuitl|Analysed=Yes']
# ['10', 'catca', 'catqui', 'AUX', '_', 'Aspect=Imp|Number[subj]=Sing|Person[subj]=3|Tense=Past|VerbForm=Fin', '9', 'cop', '9:cop', 'Folio=1r|Paragraph=1|Line=2|Norm=catca|Analysed=Yes']
# ['11', ',', ',', 'PUNCT', '_', '', '13', 'punct', '13:punct', 'Folio=1r|Paragraph=1|Line=2|Norm=,|Analysed=Yes']
# ['12', 'in', 'in', 'SCONJ', '_', '_', '13', 'mark', '13:mark', 'Orig=inqujte¶·tzammatia|Folio=1r,1r|Paragraph=1,1|Line=2,3|Norm=in']
# ['13', 'qujtetzammatia', 'tetzammatia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '9', 'conj', '9:conj', 'Orig=inqujte¶·tzammatia|Folio=1r,1r|Paragraph=1,1|Line=2,3|Norm=quitetzammatia|Analysed=Yes']
# ['14', ',', ',', 'PUNCT', '_', '', '16', 'punct', '16:punct', 'Folio=1r|Paragraph=1|Line=3|Norm=,|Analysed=Yes']
# ['15', 'in', 'in', 'DET', '_', '_', '16', 'det', '16:det', 'Folio=1r|Paragraph=1|Line=3|Norm=in']
# ['16', 'iehoantin', 'yehhuan', 'PRON', '_', 'Number=Plur|Person=3|PronType=Prs', '13', 'nsubj', '13:nsubj', 'Folio=1r|Paragraph=1|Line=3|Norm=yehhuantin|Gloss=ellos|Analysed=Yes']
# ['17', 'mexica', 'mexicatl', 'NOUN', '_', 'Number=Plur', '16', 'appos', '16:appos', 'Folio=1r|Paragraph=1|Line=3|Norm=mexica|Analysed=Yes']
# ['18', '.', '.', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=1r|Paragraph=1|Line=3|Norm=.|Analysed=Yes']
# ['1', 'Jc', 'ic', 'ADV', '_', '_', '2', '_', '2:dep', 'Folio=1r|Paragraph=2|Line=1|Norm=Ic']
# ['2', 'ce', 'ce', 'NUM', '_', '_', '3', '_', '3:dep', 'Folio=1r|Paragraph=2|Line=1|Norm=ce|AmbigNorm=True|Override=False|Gloss=uno']
# ['3', 'capitulo', 'capítulo', 'NOUN', '_', 'State=Abs', '6', '_', '6:dep', 'Folio=1r|Paragraph=2|Line=1|Norm=capítulo|Analysed=Yes']
# ['4', ',', ',', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=1r|Paragraph=2|Line=1|Norm=,|Analysed=Yes']
# ['5', 'vncan', 'oncan', 'ADV', '_', '', '6', '_', '6:dep', 'Folio=1r|Paragraph=2|Line=1|Norm=oncan|Gloss=aquí|Analysed=Yes']
# ['6', 'mitoa', 'ihtoa', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Reflex[obj]=Yes|Subcat=Tran|Tense=Pres|VerbForm=Fin', '0', 'root', '0:root', 'Folio=1r|Paragraph=2|Line=1|Norm=mihtoa|Analysed=Yes']
# ['7', ',', ',', 'PUNCT', '_', '', '9', 'punct', '9:punct', 'Folio=1r|Paragraph=2|Line=1|Norm=,|Analysed=Yes']
# ['8', 'in', 'in', 'DET|SCONJ', '_', '_', '9', '_', '9:dep', 'Orig=inte¶·tzaujtl|Folio=1r,1r|Paragraph=2,2|Line=1,2|Norm=in']
# ['9', 'tetzaujtl', 'tetzahuitl', 'NOUN', '_', 'State=Abs', '6', '_', '6:dep', 'Orig=inte¶·tzaujtl|Folio=1r,1r|Paragraph=2,2|Line=1,2|Norm=tetzahuitl|Analysed=Yes']
# ['10', 'in', 'in', 'SCONJ', '_', '_', '11', '_', '11:dep', 'Orig=inqujtetzammatia|Folio=1r|Paragraph=2|Line=2|Norm=in']
# ['11', 'qujtetzammatia', 'tetzammatia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '9', 'acl', '9:acl', 'Orig=inqujtetzammatia|Folio=1r|Paragraph=2|Line=2|Norm=quitetzammatia|Analysed=Yes']
# ['12', ':', ':', 'PUNCT', '_', '', '15', 'punct', '15:punct', 'Folio=1r|Paragraph=2|Line=2|Norm=:|Analysed=Yes']
# ['13', 'in', 'in', 'DET|SCONJ', '_', '_', '14', '_', '14:dep', 'Orig=iniquac¶|Folio=1r|Paragraph=2|Line=2|Norm=in']
# ['14', 'iquac', 'ihcuac', 'ADV', '_', '_', '15', '_', '15:dep', 'Orig=iniquac¶|Folio=1r|Paragraph=2|Line=2|Norm=ihcuac|Gloss=en.el.momento']
# ['15', 'ioaltica', 'yohualtica', 'ADV', '_', '', '18', '_', '18:dep', 'Folio=1r|Paragraph=2|Line=3|Norm=yohualtica|Temporal=Yes|Analysed=Yes']
# ['16', ',', ',', 'PUNCT', '_', '', '18', 'punct', '18:punct', 'Folio=1r|Paragraph=2|Line=3|Norm=,|Analysed=Yes']
# ['17', 'aca', 'aca', 'DET|PRON', '_', '_', '18', '_', '18:dep', 'Folio=1r|Paragraph=2|Line=3|Norm=aca']
# ['18', 'quicaquja', 'caqui', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '11', '_', '11:dep', 'Folio=1r|Paragraph=2|Line=3|Norm=quicaquiya|Analysed=Yes']
# ['19', ':', ':', 'PUNCT', '_', '', '21', 'punct', '21:punct', 'Folio=1r|Paragraph=2|Line=3|Norm=:|Analysed=Yes']
# ['20', 'in', 'in', 'DET|SCONJ', '_', '_', '21', '_', '21:dep', 'Folio=1r|Paragraph=2|Line=3|Norm=in']
# ['21', 'chocaia', 'choca', 'VERB', '_', 'Aspect=Imp|Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Past|VerbForm=Fin', '18', '_', '18:dep', 'Folio=1r|Paragraph=2|Line=3|Norm=chocaya|Analysed=Yes']
# ['22', ':', ':', 'PUNCT', '_', '', '24', 'punct', '24:punct', 'Folio=1r|Paragraph=2|Line=3|Norm=:|Analysed=Yes']
# ['23', 'itla', 'tla', 'PRON', '_', '_', '24', '_', '24:dep', 'Folio=1r|Paragraph=2|Line=4|Norm=itla|AmbigNorm=True|Override=False|Gloss=algo']
# ['24', 'tequanj', 'tecuani', 'NOUN', '_', 'State=Abs', '21', '_', '21:dep', 'Folio=1r|Paragraph=2|Line=4|Norm=tecuani|Gloss=bestia|Analysed=Yes']
# ['25', ',', ',', 'PUNCT', '_', '', '32', 'punct', '32:punct', 'Folio=1r|Paragraph=2|Line=4|Norm=,|Analysed=Yes']
# ['26', 'in', 'in', 'DET|SCONJ', '_', '_', '32', '_', '32:dep', 'Orig=inanoce|Folio=1r|Paragraph=2|Line=4|Norm=in']
# ['27', 'anoce', 'anoce', 'CCONJ', '_', '_', '32', '_', '32:dep', 'Orig=inanoce|Folio=1r|Paragraph=2|Line=4|Norm=anoce']
# ['28', ',', ',', 'PUNCT', '_', '', '32', 'punct', '32:punct', 'Folio=1r|Paragraph=2|Line=4|Norm=,|Analysed=Yes']
# ['29', 'iuhquj', 'iuhqui', 'ADV', '_', '', '32', '_', '32:dep', 'Folio=1r|Paragraph=2|Line=4|Norm=iuhqui|Gloss=así|Analysed=Yes']
# ['30', 'aca', 'aca', 'DET|PRON', '_', '_', '31', '_', '31:dep', 'Folio=1r|Paragraph=2|Line=4|Norm=aca']
# ['31', 'ilama', 'ilamatl', 'NOUN', '_', 'Number[psor]=Sing|Person[psor]=3|State=Pos', '32', '_', '32:dep', 'Orig=ilamachocaia|Folio=1r|Paragraph=2|Line=5|Norm=ilama|Analysed=Yes']
# ['32', 'chocaia', 'choca', 'VERB', '_', 'Aspect=Imp|Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Past|VerbForm=Fin', '21', '_', '21:dep', 'Orig=ilamachocaia|Folio=1r|Paragraph=2|Line=5|Norm=chocaya|Analysed=Yes']
# ['33', ':', ':', 'PUNCT', '_', '', '38', 'punct', '38:punct', 'Folio=1r|Paragraph=2|Line=5|Norm=:|Analysed=Yes']
# ['34', 'auh', 'auh', 'CCONJ', '_', '_', '38', '_', '38:dep', 'Folio=1r|Paragraph=2|Line=5|Norm=auh|Gloss=y']
# ['35', 'iequene', 'yequene', 'ADV', '_', '', '38', '_', '38:dep', 'Folio=1r|Paragraph=2|Line=5|Norm=yequene|Analysed=Yes']
# ['36', ',', ',', 'PUNCT', '_', '', '38', 'punct', '38:punct', 'Folio=1r|Paragraph=2|Line=5|Norm=,|Analysed=Yes']
# ['37', 'in', 'in', 'DET|SCONJ', '_', '_', '38', '_', '38:dep', 'Orig=intlejn¶|Folio=1r|Paragraph=2|Line=5|Norm=in']
# ['38', 'tlejn', 'tlein', 'PRON', '_', '_', '11', '_', '11:dep', 'Orig=intlejn¶|Folio=1r|Paragraph=2|Line=5|Norm=tlein']
# ['39', 'qujtoaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '38', '_', '38:dep', 'Folio=1r|Paragraph=2|Line=6|Norm=quihtoaya|Analysed=Yes']
# ['40', ',', ',', 'PUNCT', '_', '', '41', 'punct', '41:punct', 'Folio=1r|Paragraph=2|Line=6|Norm=,|Analysed=Yes']
# ['41', 'tonalpouhque', 'tonalpouhqui', 'NOUN', '_', '_', '39', '_', '39:dep', 'Folio=1r|Paragraph=2|Line=6|Norm=tonalpouhque|Gloss=astrólogo|Split=tonal·pouhqui']
# ['42', ':', ':', 'PUNCT', '_', '', '44', 'punct', '44:punct', 'Folio=1r|Paragraph=2|Line=6|Norm=:|Analysed=Yes']
# ['43', 'in', 'in', 'DET|SCONJ', '_', '_', '44', '_', '44:dep', 'Folio=1r|Paragraph=2|Line=6|Norm=in']
# ['44', 'mjtovaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[subj]=Plur,Sing|Person[subj]=3|Reflex[obj]=Yes|Subcat=Tran|Tense=Past|VerbForm=Fin', '41', 'acl', '41:acl', 'Orig=mjtova¶·ia|Folio=1r,1r|Paragraph=2,2|Line=6,7|Norm=mihtoaya|Analysed=Yes']
# ['45', 'tlamatinjme', 'tlamatini', 'NOUN', '_', 'Number=Plur', '44', '_', '44:dep', 'Folio=1r|Paragraph=2|Line=7|Norm=tlamatinime|Analysed=Yes']
# ['46', 'catca', 'catqui', 'AUX', '_', 'Aspect=Imp|Number[subj]=Sing|Person[subj]=3|Tense=Past|VerbForm=Fin', '45', '_', '45:dep', 'Folio=1r|Paragraph=2|Line=7|Norm=catca|Analysed=Yes']
# ['47', '.', '.', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=1r|Paragraph=2|Line=7|Norm=.|Analysed=Yes']
# ['1', 'In', 'in', 'DET|SCONJ', '_', '_', '3', '_', '_', 'Orig=I·nievecauh|Folio=1r,1r|Paragraph=3,3|Line=1,1|Norm=In']
# ['2', 'ie', 'ye', 'ADV', '_', '_', '3', '_', '_', 'Orig=I·nievecauh|Folio=1r,1r|Paragraph=3,3|Line=1,1|Norm=ye|AmbigNorm=True|Override=True']
# ['3', 'vecauh', 'huecauh', 'ADV', '_', '', '11', '_', '_', 'Orig=I·nievecauh|Folio=1r,1r|Paragraph=3,3|Line=1,1|Norm=huecauh|Analysed=Yes']
# ['4', ',', ',', 'PUNCT', '_', '', '7', 'punct', '_', 'Folio=1r|Paragraph=3|Line=1|Norm=,|Analysed=Yes']
# ['5', 'in', 'in', 'DET|SCONJ', '_', '_', '7', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=1|Norm=in']
# ['6', 'oc', 'oc', 'ADV', '_', '', '7', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=1|Norm=oc|Analysed=Yes']
# ['7', 'tlateotoco', 'tlateotoco', 'NOUN', '_', 'NounClass=Loc', '11', '_', '_', 'Orig=tlateo¶·toco|Folio=1r,1r|Paragraph=3,3|Line=1,2|Norm=tlateotoco|Gloss=en.la.idolatria|Locative=Yes|Analysed=Yes']
# ['8', ':', ':', 'PUNCT', '_', '', '11', 'punct', '_', 'Folio=1r|Paragraph=3|Line=2|Norm=:|Analysed=Yes']
# ['9', 'in', 'in', 'DET|SCONJ', '_', '_', '11', '_', '_', 'Orig=injuh|Folio=1r|Paragraph=3|Line=2|Norm=in']
# ['10', 'juh', 'iuh', 'ADV', '_', '', '11', '_', '_', 'Orig=injuh|Folio=1r|Paragraph=3|Line=2|Norm=iuh|Gloss=así|Analysed=Yes']
# ['11', 'quitoa', 'ihtoa', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '0', 'root', '_', 'Folio=1r|Paragraph=3|Line=2|Norm=quihtoa|Analysed=Yes']
# ['12', ',', ',', 'PUNCT', '_', '', '14', 'punct', '_', 'Folio=1r|Paragraph=3|Line=2|Norm=,|Analysed=Yes']
# ['13', 'cequjntin', 'cequi', 'PRON', '_', '_', '14', '_', '_', 'Orig=ce¶·qujntin|Folio=1r,1r|Paragraph=3,3|Line=2,3|Norm=cequintin|Gloss=algunos']
# ['14', 'veuetque', 'huehuetque', 'NOUN', '_', 'Number=Plur', '11', '_', '_', 'Folio=1r|Paragraph=3|Line=3|Norm=huehuetque|Gloss=viejos|Analysed=Yes']
# ['15', ',', ',', 'PUNCT', '_', '', '16', 'punct', '_', 'Folio=1r|Paragraph=3|Line=3|Norm=,|Analysed=Yes']
# ['16', 'veuetlaca', 'huehuetlacatl', 'NOUN', '_', 'Number=Plur', '14', '_', '_', 'Orig=ve¶·ue·tlaca|Folio=1r,1r,1r|Paragraph=3,3,3|Line=3,4,4|Norm=huehuetlaca|Gloss=ancianos|Split=huehue·tlaca|Analysed=Yes']
# ['17', ':', ':', 'PUNCT', '_', '', '20', 'punct', '_', 'Folio=1r|Paragraph=3|Line=4|Norm=:|Analysed=Yes']
# ['18', 'in', 'in', 'DET|SCONJ', '_', '_', '20', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=4|Norm=in']
# ['19', 'oc', 'oc', 'ADV', '_', '', '20', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=4|Norm=oc|Analysed=Yes']
# ['20', 'titixcavitoque', 'ixcahuia', 'VERB', '_', 'Number[subj]=Plur|Person[subj]=1|Reflex[obj]=Yes|Subcat=Tran', '11', '_', '_', 'Orig=titixca¶·vitoque|Folio=1r,1r|Paragraph=3,3|Line=4,5|Norm=titixcahuitoque|Analysed=Yes']
# ['21', ',', ',', 'PUNCT', '_', '', '24', 'punct', '_', 'Folio=1r|Paragraph=3|Line=5|Norm=,|Analysed=Yes']
# ['22', 'in', 'in', 'DET|SCONJ', '_', '_', '24', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=5|Norm=in']
# ['23', 'oc', 'oc', 'ADV', '_', '', '24', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=5|Norm=oc|Analysed=Yes']
# ['24', 'titomattoque', 'mati', 'VERB', '_', 'Number[subj]=Plur|Person[subj]=1|Reflex[obj]=Yes|Subcat=Tran', '11', '_', '_', 'Folio=1r|Paragraph=3|Line=5|Norm=titomattoque|Analysed=Yes']
# ['25', ',', ',', 'PUNCT', '_', '', '29', 'punct', '_', 'Folio=1r|Paragraph=3|Line=5|Norm=,|Analysed=Yes']
# ['26', 'in', 'in', 'DET|SCONJ', '_', '_', '29', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=5|Norm=in']
# ['27', 'oc', 'oc', 'ADV', '_', '', '29', '_', '_', 'Orig=inoc|Folio=1r|Paragraph=3|Line=5|Norm=oc|Analysed=Yes']
# ['28', 'totlalpan', 'tlalpan', 'NOUN', '_', 'NounClass=Loc|Number[psor]=Plur|Person[psor]=1|State=Pos', '29', '_', '_', 'Orig=to¶·tlalpan|Folio=1r,1r|Paragraph=3,3|Line=5,6|Norm=totlalpan|Locative=Yes|Analysed=Yes']
# ['29', 'tiqujtoaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Sing|Person[obj]=3|Person[subj]=2|Subcat=Tran|Tense=Past|VerbForm=Fin', '11', '_', '_', 'Folio=1r|Paragraph=3|Line=6|Norm=tiquihtoaya|Analysed=Yes']
# ['30', ':', ':', 'PUNCT', '_', '', '33', 'punct', '_', 'Folio=1r|Paragraph=3|Line=6|Norm=:|Analysed=Yes']
# ['31', 'in', 'in', 'DET|SCONJ', '_', '_', '33', '_', '_', 'Orig=inaia·aque|Folio=1r,1r|Paragraph=3,3|Line=6,6|Norm=in']
# ['32', 'aiaaque', 'aya', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Past|VerbForm=Fin', '33', '_', '_', 'Orig=inaia·aque|Folio=1r,1r|Paragraph=3,3|Line=6,6|Norm=ayaque|Analysed=Yes']
# ['33', 'technelotoque', 'neloa', 'VERB', '_', 'Number[obj]=Plur|Number[subj]=Plur,Sing|Person[obj]=1|Person[subj]=3|Subcat=Tran', '11', '_', '_', 'Orig=tech¶·nelotoque|Folio=1r,1r|Paragraph=3,3|Line=6,7|Norm=technelotoque|Analysed=Yes']
# ['34', ':', ':', 'PUNCT', '_', '', '37', 'punct', '_', 'Folio=1r|Paragraph=3|Line=7|Norm=:|Analysed=Yes']
# ['35', 'in', 'in', 'DET|SCONJ', '_', '_', '37', '_', '_', 'Orig=inaiaque|Folio=1r|Paragraph=3|Line=7|Norm=in']
# ['36', 'aiaque', 'aya', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Past|VerbForm=Fin', '37', '_', '_', 'Orig=inaiaque|Folio=1r|Paragraph=3|Line=7|Norm=ayaque|Analysed=Yes']
# ['37', 'totlah', 'tlahtli', 'NOUN', '_', 'Number[psor]=Plur|Person[psor]=1|State=Pos', '33', '_', '_', 'Folio=1r|Paragraph=3|Line=7|Norm=totlah|Gloss=nuestros.tíos|Analysed=Yes']
# ['38', 'onoque', 'onoc', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '33', '_', '_', 'Folio=1r|Paragraph=3|Line=7|Norm=onoque|Analysed=Yes']
# ['39', '.', '.', 'PUNCT', '_', '', '11', 'punct', '_', 'Folio=1r|Paragraph=3|Line=7|Norm=.|Analysed=Yes']
# ['1', 'Yzqujtlamantli', 'izquitlamantli', 'NOUN', '_', 'Number=Plur', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=8|Norm=Izquitlamanti|Analysed=Yes']
# ['2', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=8|Norm=,|Analysed=Yes']
# ['3', 'y', 'in', 'CCONJ', '_', '_', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=8|Norm=in|AmbigNorm=True|Override=True']
# ['4', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=8|Norm=,|Analysed=Yes']
# ['5', 'in', 'in', 'DET|SCONJ|PRON', '_', '_', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=8|Norm=in']
# ['6', 'qujtetzammatia', 'tetzammatia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '_', '_', '_', 'Orig=quj·tetzamma¶·tia|Folio=1r,1r,1r|Paragraph=3,3,3|Line=8,8,9|Norm=quitetzammatia|Analysed=Yes']
# ['7', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=9|Norm=,|Analysed=Yes']
# ['8', 'in', 'in', 'DET|SCONJ|PRON', '_', '_', '_', '_', '_', 'Orig=inquitetzaujttaia|Folio=1r|Paragraph=3|Line=9|Norm=in']
# ['9', 'quitetzaujttaia', 'tetzahuitta', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '_', '_', '_', 'Orig=inquitetzaujttaia|Folio=1r|Paragraph=3|Line=9|Norm=quitetzahuittaya|Analysed=Yes']
# ['10', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=9|Norm=,|Analysed=Yes']
# ['11', 'in', 'in', 'DET|SCONJ|PRON', '_', '_', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=9|Norm=in']
# ['12', 'tetzaujtl', 'tetzahuitl', 'NOUN', '_', 'State=Abs', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=9|Norm=tetzahuitl|Analysed=Yes']
# ['13', 'ipan', 'pan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=9|Norm=ipan|Analysed=Yes']
# ['14', 'quimatia', 'matia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=10|Norm=quimatia|Analysed=Yes']
# ['15', 'in', 'in', 'DET|SCONJ|PRON', '_', '_', '_', '_', '_', 'Orig=innetetzaujloia|Folio=1r|Paragraph=3|Line=10|Norm=in']
# ['16', 'netetzaujloia', 'tetzahuia', 'VERB', '_', '_', '_', '_', '_', 'Orig=innetetzaujloia|Folio=1r|Paragraph=3|Line=10|Norm=netetzahuiloya']
# ['17', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=10|Norm=,|Analysed=Yes']
# ['18', 'in', 'in', 'DET|SCONJ|PRON', '_', '_', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=10|Norm=in']
# ['19', 'tlatetzaujaia', 'tetzahuia', 'VERB', '_', '_', '_', '_', '_', 'Orig=tlatetza¶·ujaia|Folio=1r,1r|Paragraph=3,3|Line=10,11|Norm=tlatetzahuiaya']
# ['20', '.', '.', 'PUNCT', '_', '', '_', '_', '_', 'Folio=1r|Paragraph=3|Line=11|Norm=.|Analysed=Yes']
# ['1', 'Jnic', 'inic', 'ADJ', '_', '_', '2', 'amod', '_', 'Folio=1r|Paragraph=4|Line=1|Norm=Inic']
# ['2', 'centlamantli', 'centlamantli', 'NOUN', '_', 'State=Abs', '4', 'nsubj', '_', 'Folio=1r|Paragraph=4|Line=1|Norm=centlamantli|Analysed=Yes']
# ['3', ',', ',', 'PUNCT', '_', '', '4', 'punct', '_', 'Folio=1r|Paragraph=4|Line=1|Norm=,|Analysed=Yes']
# ['4', 'iehoatl', 'yehhuatl', 'PRON', '_', 'Number=Sing|Person=3|PronType=Prs', '0', 'root', '_', 'Folio=1r|Paragraph=4|Line=1|Norm=yehhuatl|Gloss=él|Analysed=Yes']
# ['5', ',', ',', 'PUNCT', '_', '', '9', 'punct', '_', 'Folio=1r|Paragraph=4|Line=1|Norm=,|Analysed=Yes']
# ['6', 'in', 'in', 'SCONJ', '_', '_', '9', 'mark', '_', 'Orig=iniquac¶|Folio=1r|Paragraph=4|Line=1|Norm=in']
# ['7', 'iquac', 'ihcuac', 'ADV', '_', '_', '9', 'mark', '_', 'Orig=iniquac¶|Folio=1r|Paragraph=4|Line=1|Norm=ihcuac|Gloss=en.el.momento']
# ['8', 'aca', 'aca', 'PRON', '_', '_', '9', 'nsubj', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=aca']
# ['9', 'quicaquia', 'caqui', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '_', '_', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=quicaquiya|Analysed=Yes']
# ['10', ':', ':', 'PUNCT', '_', '', '13', 'punct', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=:|Analysed=Yes']
# ['11', 'in', 'in', 'DET', '_', '_', '13', 'mark', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=in']
# ['12', 'tequanj', 'tecuani', 'NOUN', '_', 'State=Abs', '13', 'nsubj', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=tecuani|Gloss=bestia|Analysed=Yes']
# ['13', 'choca', 'choca', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '9', 'ccomp', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=choca|Gloss=llora|Analysed=Yes']
# ['14', ',', ',', 'PUNCT', '_', '', '17', 'punct', '_', 'Folio=1r|Paragraph=4|Line=2|Norm=,|Analysed=Yes']
# ['15', 'tequanj', 'tecuani', 'NOUN', '_', 'State=Abs', '17', 'nsubj', '_', 'Orig=te¶·quanj|Folio=1r,1r|Paragraph=4,4|Line=2,3|Norm=tecuani|Gloss=bestia|Analysed=Yes']
# ['16', 'ipan', 'pan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '17', 'obl', '_', 'Folio=1r|Paragraph=4|Line=3|Norm=ipan|Analysed=Yes']
# ['17', 'choca', 'choca', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '13', 'conj', '_', 'Folio=1r|Paragraph=4|Line=3|Norm=choca|Gloss=llora|Analysed=Yes']
# ['18', ':', ':', 'PUNCT', '_', '', '22', 'punct', '_', 'Folio=1r|Paragraph=4|Line=3|Norm=:|Analysed=Yes']
# ['19', 'in', 'in', 'SCONJ', '_', '_', '22', 'mark', '_', 'Orig=injuhquj|Folio=1r|Paragraph=4|Line=3|Norm=in']
# ['20', 'juhquj', 'iuhqui', 'ADV', '_', '', '22', 'advmod', '_', 'Orig=injuhquj|Folio=1r|Paragraph=4|Line=3|Norm=iuhqui|Gloss=así|Analysed=Yes']
# ['21', 'tecciztli', 'tecciztli', 'NOUN', '_', 'State=Abs', '22', 'nsubj', '_', 'Folio=1r|Paragraph=4|Line=3|Norm=tecciztli|Gloss=caracol|Analysed=Yes']
# ['22', 'qujpitza', 'pitza', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '9', 'advcl', '_', 'Folio=1r|Paragraph=4|Line=4|Norm=quipitza|Analysed=Yes']
# ['23', ':', ':', 'PUNCT', '_', '', '25', 'punct', '_', 'Folio=1r|Paragraph=4|Line=4|Norm=:|Analysed=Yes']
# ['24', 'tepetl', 'tepetl', 'NOUN', '_', 'State=Abs', '25', 'nsubj', '_', 'Folio=1r|Paragraph=4|Line=4|Norm=tepetl|Gloss=monte|Analysed=Yes']
# ['25', 'qujnanqujlia', 'nanquilia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '22', '_', '_', 'Folio=1r|Paragraph=4|Line=4|Norm=quinanquilia|Analysed=Yes']
# ['26', ':', ':', 'PUNCT', '_', '', '27', 'punct', '_', 'Folio=1r|Paragraph=4|Line=4|Norm=:|Analysed=Yes']
# ['27', 'tehcuiooa', 'tecuyoa', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '25', 'conj', '_', 'Orig=teh¶·cuiooa|Folio=1r,1r|Paragraph=4,4|Line=4,5|Norm=tecuyoa|Analysed=Yes']
# ['28', ',', ',', 'PUNCT', '_', '', '29', 'punct', '_', 'Folio=1r|Paragraph=4|Line=5|Norm=,|Analysed=Yes']
# ['29', 'tlaoalanja', 'tlahuilana', 'VERB', '_', '_', '25', '_', '_', 'Folio=1r|Paragraph=4|Line=5|Norm=tlahualania']
# ['30', ':', ':', 'PUNCT', '_', '', '33', 'punct', '_', 'Folio=1r|Paragraph=4|Line=5|Norm=:|Analysed=Yes']
# ['31', 'iuhqujn', 'iuhquin', 'ADV', '_', '', '33', 'advmod', '_', 'Orig=iuhqujn|Folio=1r|Paragraph=4|Line=5|Norm=iuhquin|Gloss=así|Analysed=Yes']
# ['32', 'ilamapul', 'ilamatl', 'NOUN', '_', '_', '33', 'nsubj', '_', 'Orig=ilama¶·pul|Folio=1r,1r|Paragraph=4,4|Line=5,6|Norm=ilamapol|Gloss=vieja']
# ['33', 'choca', 'choca', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '29', 'advcl', '_', 'Folio=1r|Paragraph=4|Line=6|Norm=choca|Gloss=llora|Analysed=Yes']
# ['34', '.', '.', 'PUNCT', '_', '', '4', 'punct', '_', 'Folio=1r|Paragraph=4|Line=6|Norm=.|Analysed=Yes']
# ['1', 'Ynjn', 'inin', 'PRON', '_', '_', '3', 'dislocated', '3:dislocated', 'Folio=1r|Paragraph=4|Line=6|Norm=Inin']
# ['2', ',', ',', 'PUNCT', '_', '', '3', 'punct', '3:punct', 'Folio=1r|Paragraph=4|Line=6|Norm=,|Analysed=Yes']
# ['3', 'qujtovaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '0', 'root', '0:root', 'Folio=1r|Paragraph=4|Line=6|Norm=quitoaya|Analysed=Yes']
# ['4', 'ie', 'ye', 'ADV', '_', '_', '5', 'advmod', '5:advmod', 'Folio=1r|Paragraph=4|Line=6|Norm=ye|AmbigNorm=True|Override=False']
# ['5', 'iaomjqujz', 'yaomiqui', 'VERB', '_', '_', '3', '_', '3:dep', 'Orig=iaomj¶·qujz|Folio=1r,1r|Paragraph=4,4|Line=6,7|Norm=yaomiquiz|Split=yao·miquiz']
# ['6', ':', ':', 'PUNCT', '_', '', '9', 'punct', '9:punct', 'Folio=1r|Paragraph=4|Line=7|Norm=:|Analysed=Yes']
# ['7', 'anoço', 'anozo', 'ADV', '_', '_', '9', 'cc', '9:cc', 'Folio=1r|Paragraph=4|Line=7|Norm=anozo']
# ['8', 'ie', 'ye', 'ADV', '_', '_', '9', 'advmod', '9:advmod', 'Folio=1r|Paragraph=4|Line=7|Norm=ye|AmbigNorm=True|Override=False']
# ['9', 'mjqujz', 'miqui', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Fut|VerbForm=Fin', '5', 'conj', '5:conj', 'Folio=1r|Paragraph=4|Line=7|Norm=miquiz|Analysed=Yes']
# ['10', ',', ',', 'PUNCT', '_', '', '11', 'punct', '11:punct', 'Folio=1r|Paragraph=4|Line=7|Norm=,|Analysed=Yes']
# ['11', 'tlalmiqujz', 'miqui', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Fut|VerbForm=Fin', '9', '_', '9:dep', 'Folio=1r|Paragraph=4|Line=7|Norm=tlalmiquiz|Split=tlal·miquiz|Analysed=Yes']
# ['11.1', 'tlal', 'tlalli', 'NOUN', '_', '_', '_', '_', '11:obl', 'Incorporated=Yes']
# ['12', ':', ':', 'PUNCT', '_', '', '17', 'punct', '17:punct', 'Folio=1r|Paragraph=4|Line=7|Norm=:|Analysed=Yes']
# ['13', 'anoço', 'anozo', 'ADV', '_', '_', '17', '_', '17:dep', 'Folio=1r|Paragraph=4|Line=8|Norm=anozo']
# ['14', ',', ',', 'PUNCT', '_', '', '17', 'punct', '17:punct', 'Folio=1r|Paragraph=4|Line=8|Norm=,|Analysed=Yes']
# ['15', 'ie', 'ye', 'ADV', '_', '_', '17', 'advmod', '17:advmod', 'Folio=1r|Paragraph=4|Line=8|Norm=ye|AmbigNorm=True|Override=False']
# ['16', 'itla', 'tla', 'PRON', '_', '_', '17', 'nsubj', '17:nsubj', 'Folio=1r|Paragraph=4|Line=8|Norm=itla|AmbigNorm=True|Override=False|Gloss=algo']
# ['17', 'commonamjctiz', 'monamictia', 'VERB', '_', 'Movement=And|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Fut|VerbForm=Fin', '5', 'conj', '5:conj', 'Orig=com·monamjctiz|Folio=1r,1r|Paragraph=4,4|Line=8,8|Norm=commonamictiz|Analysed=Yes']
# ['18', ',', ',', 'PUNCT', '_', '', '19', 'punct', '19:punct', 'Folio=1r|Paragraph=4|Line=8|Norm=,|Analysed=Yes']
# ['19', 'icnoiotl', 'icnoyotl', 'NOUN', '_', 'State=Abs', '17', 'dislocated', '17:dislocated', 'Orig=ic¶·noiotl|Folio=1r,1v|Paragraph=4,5|Line=8,10|Norm=icnoyotl|Gloss=pobreza|Analysed=Yes']
# ['20', ':', ':', 'PUNCT', '_', '', '22', 'punct', '22:punct', 'Folio=1v|Paragraph=5|Line=10|Norm=:|Analysed=Yes']
# ['21', 'aco', 'azo', 'ADV', '_', '', '22', '_', '22:dep', 'Folio=1v|Paragraph=5|Line=10|Norm=azo|Gloss=quizás|Analysed=Yes']
# ['22', 'monamacaz', 'namaca', 'VERB', '_', '_', '5', 'conj', '5:conj', 'Folio=1v|Paragraph=5|Line=10|Norm=monamacaz']
# ['23', ',', ',', 'PUNCT', '_', '', '24', 'punct', '24:punct', 'Folio=1v|Paragraph=5|Line=10|Norm=,|Analysed=Yes']
# ['24', 'motlanamjctiz', 'tlanamictia', 'VERB', '_', '_', '22', '_', '22:dep', 'Orig=motlanamjc¶·tiz|Folio=1v,1v|Paragraph=5,5|Line=10,11|Norm=motlanamictiz|Root=namictia']
# ['25', ':', ':', 'PUNCT', '_', '', '29', 'punct', '29:punct', 'Folio=1v|Paragraph=5|Line=11|Norm=:|Analysed=Yes']
# ['26', 'anoço', 'anozo', 'ADV', '_', '_', '29', '_', '29:dep', 'Folio=1v|Paragraph=5|Line=11|Norm=anozo']
# ['27', 'ipilhoan', 'pilli', 'NOUN', '_', 'Number=Plur|Number[psor]=Sing|Person[psor]=3|State=Pos', '29', 'dislocated', '29:dislocated', 'Folio=1v|Paragraph=5|Line=11|Norm=ipilhuan|Analysed=Yes']
# ['28', 'ceme', 'ce', 'PRON', '_', '_', '29', 'obj', '29:obj', 'Folio=1v|Paragraph=5|Line=11|Norm=cemeh|Gloss=unos']
# ['29', 'quinmonamaqujliz', 'namaquilia', 'VERB', '_', 'Number[obj]=Plur|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Reflex[iobj]=Yes|Subcat=Ditr|Tense=Fut|VerbForm=Fin', '5', 'conj', '5:conj', 'Orig=quin·mona¶·maqujliz|Folio=1v,1v,1v|Paragraph=5,5,5|Line=11,11,12|Norm=quinmonamaquiliz|Analysed=Yes']
# ['30', ',', ',', 'PUNCT', '_', '', '31', 'punct', '31:punct', 'Folio=1v|Paragraph=5|Line=12|Norm=,|Analysed=Yes']
# ['31', 'qujntlanamjctiz', 'tlanamictia', 'VERB', '_', '_', '29', '_', '29:dep', 'Orig=qujn·tlanamjctiz|Folio=1v,1v|Paragraph=5,5|Line=12,12|Norm=quintlanamictiz|Root=namictia']
# ['32', ':', ':', 'PUNCT', '_', '', '33', 'punct', '33:punct', 'Folio=1v|Paragraph=5|Line=12|Norm=:|Analysed=Yes']
# ['33', 'qujntlatlaculnamjctiz', 'namictia', 'VERB', '_', 'Number[obj]=Plur|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Fut|VerbForm=Fin', '29', '_', '29:dep', 'Orig=qujntlatlacul¶·namjctiz|Folio=1v,1v|Paragraph=5,5|Line=12,13|Norm=quintlatlacolnamictiz|Incorp[obj]=tlatlacol|Root=namictia|Split=quintlatlacol·namictiz|Analysed=Yes']
# ['33.1', 'tlatlacol', 'tlatlacolli', 'NOUN', '_', '_', '_', '_', '_', 'Incorporated=Yes']
# ['34', ',', ',', 'PUNCT', '_', '', '36', 'punct', '36:punct', 'Folio=1v|Paragraph=5|Line=13|Norm=,|Analysed=Yes']
# ['35', 'icnoiotl', 'icnoyotl', 'NOUN', '_', 'State=Abs', '36', 'nsubj', '36:nsubj', 'Folio=1v|Paragraph=5|Line=13|Norm=icnoyotl|Gloss=pobreza|Analysed=Yes']
# ['36', 'calaqujz', 'calaqui', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Fut|VerbForm=Fin', '5', 'conj', '5:conj', 'Folio=1v|Paragraph=5|Line=13|Norm=calaquiz|Analysed=Yes']
# ['37', ',', ',', 'PUNCT', '_', '', '39', 'punct', '39:punct', 'Folio=1v|Paragraph=5|Line=13|Norm=,|Analysed=Yes']
# ['38', 'in', 'in', 'DET', '_', '_', '39', 'det', '39:det', 'Orig=inj·nextitlan|Folio=1v,1v|Paragraph=5,5|Line=13,13|Norm=in']
# ['39', 'jnextitlan', 'nextitlan', 'NOUN', '_', 'Number[psor]=Sing|Person[psor]=3|State=Pos', '36', 'obl', '36:obl', 'Orig=inj·nextitlan|Folio=1v,1v|Paragraph=5,5|Line=13,13|Norm=inextitlan|Locative=Yes|Split=inex·titlan|Gloss=su.hogar|Analysed=Yes']
# ['40', ',', ',', 'PUNCT', '_', '', '42', 'punct', '42:punct', 'Folio=1v|Paragraph=5|Line=13|Norm=,|Analysed=Yes']
# ['41', 'in', 'in', 'DET', '_', '_', '42', 'det', '42:det', 'Orig=injtlecujllan|Folio=1v|Paragraph=5|Line=14|Norm=in']
# ['42', 'jtlecujllan', 'tlecuillan', 'NOUN', '_', 'Number[psor]=Sing|Person[psor]=3|State=Pos', '39', 'appos:difras', '39:appos:difras', 'Orig=injtlecujllan|Folio=1v|Paragraph=5|Line=14|Norm=itlecuillan|Locative=Yes|Split=itlecuil·lan|Gloss=su.hogar|Analysed=Yes']
# ['43', ':', ':', 'PUNCT', '_', '', '45', 'punct', '45:punct', 'Folio=1v|Paragraph=5|Line=14|Norm=:|Analysed=Yes']
# ['44', 'atl', 'atl', 'NOUN', '_', 'State=Abs', '45', 'nsubj', '45:nsubj', 'Folio=1v|Paragraph=5|Line=14|Norm=atl|Gloss=agua|Analysed=Yes']
# ['45', 'neneciz', 'nehneci', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Fut|VerbForm=Fin', '3', 'conj', '3:conj', 'Folio=1v|Paragraph=5|Line=14|Norm=nehneciz|Analysed=Yes']
# ['46', 'in', 'in', 'DET', '_', '_', '47', 'det', '47:det', 'Orig=injchan|Folio=1v|Paragraph=5|Line=14|Norm=in']
# ['47', 'jchan', 'chantli', 'NOUN', '_', 'Number[psor]=Sing|Person[psor]=3|State=Pos', '45', 'obl', '45:obl', 'Orig=injchan|Folio=1v|Paragraph=5|Line=14|Norm=ichan|Gloss=su.casa|Analysed=Yes']
# ['48', '.', '.', 'PUNCT', '_', '', '3', 'punct', '3:punct', 'Folio=1v|Paragraph=5|Line=14|Norm=.|Analysed=Yes']
# ['1', 'Yn', 'in', 'DET', '_', '_', '3', '_', '_', 'Orig=Y·njqc¶|Folio=1v,1v|Paragraph=5,5|Line=14,14|Norm=In']
# ['2', 'jqc', 'ihcuac', 'ADV', '_', '_', '1', '_', '_', 'Orig=Y·njqc¶|Folio=1v,1v|Paragraph=5,5|Line=14,14|Norm=ihcuac|Gloss=en.el.momento']
# ['3', 'oiuh', 'oyohua', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Past|VerbForm=Fin', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=oyouh|Analysed=Yes']
# ['4', 'ipan', 'pan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '5', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=ipan|Analysed=Yes']
# ['5', 'muchiuh', 'chihua', 'VERB', '_', '_', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=mochiuh']
# ['6', ',', ',', 'PUNCT', '_', '', '11', 'punct', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=,|Analysed=Yes']
# ['7', 'y', 'y', 'CCONJ', '_', '_', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=y|AmbigNorm=True|Override=False']
# ['8', ':', ':', 'PUNCT', '_', '', '11', 'punct', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=:|Analysed=Yes']
# ['9', 'njman', 'niman', 'ADV', '_', '', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=niman|Analysed=Yes']
# ['10', 'ic', 'ic', 'ADV', '_', '_', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=ic']
# ['11', 'iauh', 'ya', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '0', 'root', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=yauh|Analysed=Yes']
# ['12', ',', ',', 'PUNCT', '_', '', '13', 'punct', '_', 'Folio=1v|Paragraph=5|Line=15|Norm=,|Analysed=Yes']
# ['13', 'qujttaz', 'itta', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Fut|VerbForm=Fin', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=16|Norm=quittaz|Analysed=Yes']
# ['14', 'in', 'in', 'DET', '_', '_', '15', 'det', '_', 'Orig=intonalpouhquj|Folio=1v|Paragraph=5|Line=16|Norm=in']
# ['15', 'tonalpouhquj', 'tonalpouhqui', 'NOUN', '_', 'State=Abs', '13', 'obj', '_', 'Orig=intonalpouhquj|Folio=1v|Paragraph=5|Line=16|Norm=tonalpouhqui|Analysed=Yes']
# ['16', ':', ':', 'PUNCT', '_', '', '18', 'punct', '_', 'Folio=1v|Paragraph=5|Line=16|Norm=:|Analysed=Yes']
# ['17', 'vmpa', 'ompa', 'ADV', '_', '', '18', 'advmod', '_', 'Folio=1v|Paragraph=5|Line=16|Norm=ompa|Gloss=allá|Analysed=Yes']
# ['18', 'quellaquaoa', 'ellacuahua', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '11', '_', '_', 'Orig=quella¶·quaoa|Folio=1v,1v|Paragraph=5,5|Line=16,17|Norm=quellacuahua|Analysed=Yes']
# ['19', ',', ',', 'PUNCT', '_', '', '20', 'punct', '_', 'Folio=1v|Paragraph=5|Line=17|Norm=,|Analysed=Yes']
# ['20', 'qujtlapaloa', 'tlahpaloa', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '18', 'conj', '_', 'Folio=1v|Paragraph=5|Line=17|Norm=quitlahpaloa|Analysed=Yes']
# ['21', ':', ':', 'PUNCT', '_', '', '22', 'punct', '_', 'Folio=1v|Paragraph=5|Line=17|Norm=:|Analysed=Yes']
# ['22', 'qujlvia', 'ilhuia', 'VERB', '_', '_', '11', '_', '_', 'Folio=1v|Paragraph=5|Line=17|Norm=quilhuia']
# ['23', '.', '.', 'PUNCT', '_', '', '11', 'punct', '_', 'Folio=1v|Paragraph=5|Line=17|Norm=.|Analysed=Yes']
# ['1', 'Timotolinja', 'tolinia', 'NOUN', '_', 'Number[subj]=Sing|Person[subj]=2', '0', 'root', '_', 'Orig=Timotoli¶·nja|Folio=1v,1v|Paragraph=5,5|Line=17,18|Norm=Timotolinia']
# ['2', 'xole', 'xolo', 'NOUN', '_', 'Clitic=Voc|State=Abs', '1', 'vocative', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=xole|Gloss=paje|Analysed=Yes']
# ['3', ',', ',', 'PUNCT', '_', '', '4', 'punct', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=,|Analysed=Yes']
# ['4', 'xolotze', 'xolo', 'NOUN', '_', 'Case=Voc', '2', 'conj', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=xolotze|Gloss=paje']
# ['5', ',', ',', 'PUNCT', '_', '', '6', 'punct', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=,|Analysed=Yes']
# ['6', 'telpuchtle', 'telpochtli', 'NOUN', '_', 'Clitic=Voc|State=Abs', '2', 'conj', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=telpochtle|Analysed=Yes']
# ['7', ',', ',', 'PUNCT', '_', '', '8', 'punct', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=,|Analysed=Yes']
# ['8', 'tiacave', 'tiacauh', 'NOUN', '_', 'Clitic=Voc|State=Abs', '2', 'conj', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=tiacahue|Gloss=valiente.hombre|Analysed=Yes']
# ['9', ':', ':', 'PUNCT', '_', '', '10', 'punct', '_', 'Folio=1v|Paragraph=5|Line=18|Norm=:|Analysed=Yes']
# ['10', 'ca', 'cah|ca', 'VERB', '_', '_', '1', '_', '_', 'Orig=canel|Folio=1v|Paragraph=5|Line=19|Norm=ca|AmbigNorm=True|Override=False']
# ['11', 'nel', 'nel', 'ADV', '_', '_', '12', '_', '_', 'Orig=canel|Folio=1v|Paragraph=5|Line=19|Norm=nel|Gloss=ya']
# ['12', 'tictemoa', 'temoa', 'VERB', '_', '_', '10', '_', '_', 'Folio=1v|Paragraph=5|Line=19|Norm=tictemoa']
# ['13', ',', ',', 'PUNCT', '_', '', '14', 'punct', '_', 'Folio=1v|Paragraph=5|Line=19|Norm=,|Analysed=Yes']
# ['14', 'tiqujtlanj', 'tiquitlani', 'NOUN', '_', '_', '12', '_', '_', 'Orig=tiquj·tlanj|Folio=1v,1v|Paragraph=5,5|Line=19,19|Norm=tiquitlani']
# ['15', ',', ',', 'PUNCT', '_', '', '17', 'punct', '_', 'Folio=1v|Paragraph=5|Line=19|Norm=,|Analysed=Yes']
# ['16', 'in', 'in', 'DET|SCONJ', '_', '_', '17', '_', '_', 'Folio=1v|Paragraph=5|Line=19|Norm=in']
# ['17', 'mellaquaoaloca', 'ellacuahua', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Reflex[iobj]=Yes|Subcat=Tran|Voice=Pass', '14', '_', '_', 'Orig=mellaqua¶·oaloca|Folio=1v,1v|Paragraph=5,5|Line=19,20|Norm=mellacuahualoca|Analysed=Yes']
# ['18', ':', ':', 'PUNCT', '_', '', '19', 'punct', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=:|Analysed=Yes']
# ['19', 'ca', 'cah|ca', 'VERB', '_', '_', '1', '_', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=ca|AmbigNorm=True|Override=False']
# ['20', 'ic', 'ic', 'ADV', '_', '_', '21', '_', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=ic']
# ['21', 'otiualla', 'hualla', 'VERB', '_', 'Aspect=Prior|Number[subj]=Sing|Person[subj]=2|Subcat=Intr', '19', '_', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=otihualla|Analysed=Yes']
# ['22', ',', ',', 'PUNCT', '_', '', '24', 'punct', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=,|Analysed=Yes']
# ['23', 'in', 'in', 'DET|SCONJ', '_', '_', '24', '_', '_', 'Orig=intimotezcaujco|Folio=1v|Paragraph=5|Line=20|Norm=in']
# ['24', 'timotezcaujco', 'tezcahuia', 'VERB', '_', '_', '21', '_', '_', 'Orig=intimotezcaujco|Folio=1v|Paragraph=5|Line=20|Norm=timotezcahuico']
# ['25', ',', ',', 'PUNCT', '_', '', '27', 'punct', '_', 'Folio=1v|Paragraph=5|Line=20|Norm=,|Analysed=Yes']
# ['26', 'in', 'in', 'DET|SCONJ', '_', '_', '27', '_', '_', 'Orig=intimamuxvico|Folio=1v|Paragraph=5|Line=21|Norm=in']
# ['27', 'timamuxvico', 'amoxhuia', 'VERB', '_', '_', '24', '_', '_', 'Orig=intimamuxvico|Folio=1v|Paragraph=5|Line=21|Norm=timamoxhuico']
# ['28', ':', ':', 'PUNCT', '_', '', '29', 'punct', '_', 'Folio=1v|Paragraph=5|Line=21|Norm=:|Analysed=Yes']
# ['29', 'xicchie', 'chiya', 'VERB', '_', 'Mood=Imp|Number[obj]=Sing|Number[subj]=Sing|Person[obj]=3|Person[subj]=2|Subcat=Tran|VerbForm=Fin', '1', '_', '_', 'Folio=1v|Paragraph=5|Line=21|Norm=xicchiye|Analysed=Yes']
# ['30', ',', ',', 'PUNCT', '_', '', '32', 'punct', '_', 'Folio=1v|Paragraph=5|Line=21|Norm=,|Analysed=Yes']
# ['31', 'in', 'in', 'DET|SCONJ', '_', '_', '32', '_', '_', 'Orig=intlein|Folio=1v|Paragraph=5|Line=21|Norm=in']
# ['32', 'tlein', 'tlein', 'PRON', '_', '_', '29', '_', '_', 'Orig=intlein|Folio=1v|Paragraph=5|Line=21|Norm=tlein']
# ['33', 'oticmomaceuj', 'mahcehuia', 'VERB', '_', 'Aspect=Prior|Number[obj]=Sing|Number[subj]=Sing|Person[obj]=3|Person[subj]=2|Reflex[iobj]=Yes|Subcat=Ditr|Tense=Past|VerbForm=Fin', '32', '_', '_', 'Orig=oticmo¶·maceuj|Folio=1v,1v|Paragraph=5,5|Line=21,22|Norm=oticmomacehui|Analysed=Yes']
# ['34', ':', ':', 'PUNCT', '_', '', '35', 'punct', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=:|Analysed=Yes']
# ['35', 'ca', 'cah|ca', 'VERB', '_', '_', '32', '_', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=ca|AmbigNorm=True|Override=False']
# ['36', 'amo', 'amo', 'ADV', '_', '', '38', '_', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=amo|Gloss=no|Analysed=Yes']
# ['37', 'iuijan', 'ihuiyan', 'ADV', '_', '', '38', '_', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=ihuiyan|Gloss=pacíficamente|Analysed=Yes']
# ['38', 'qualli', 'cualli', 'ADJ', '_', '_', '35', '_', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=cualli|Gloss=bueno']
# ['39', ':', ':', 'PUNCT', '_', '', '41', 'punct', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=:|Analysed=Yes']
# ['40', 'amo', 'amo', 'ADV', '_', '', '41', '_', '_', 'Folio=1v|Paragraph=5|Line=22|Norm=amo|Gloss=no|Analysed=Yes']
# ['41', 'tlacaiectli', 'tlacayectli', 'NOUN', '_', 'State=Abs', '38', '_', '_', 'Orig=tla¶·caiectli|Folio=1v,1v|Paragraph=5,5|Line=22,23|Norm=tlacayectli|Analysed=Yes']
# ['42', ',', ',', 'PUNCT', '_', '', '44', 'punct', '_', 'Folio=1v|Paragraph=5|Line=23|Norm=,|Analysed=Yes']
# ['43', 'amo', 'amo', 'ADV', '_', '', '44', '_', '_', 'Folio=1v|Paragraph=5|Line=23|Norm=amo|Gloss=no|Analysed=Yes']
# ['44', 'tlacacemelle', 'tlacacemelle', 'NOUN', '_', 'State=Abs', '38', '_', '_', 'Folio=1v|Paragraph=5|Line=23|Norm=tlacacemelle|Split=tlaca·cemelle|Gloss=monstro|Analysed=Yes']
# ['45', ':', ':', 'PUNCT', '_', '', '46', 'punct', '_', 'Folio=1v|Paragraph=5|Line=23|Norm=:|Analysed=Yes']
# ['46', 'ca', 'cah|ca', 'VERB', '_', '_', '1', '_', '_', 'Orig=caiuh|Folio=1v|Paragraph=5|Line=23|Norm=ca|AmbigNorm=True|Override=False']
# ['47', 'iuh', 'iuh', 'ADV', '_', '', '48', '_', '_', 'Orig=caiuh|Folio=1v|Paragraph=5|Line=23|Norm=iuh|Gloss=así|Analysed=Yes']
# ['48', 'conjtotiuj', 'ihtoa', 'VERB', '_', 'Movement=And|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Purpose=And|Subcat=Tran|Tense=Pres|VerbForm=Fin', '46', '_', '_', 'Orig=co¶·njtotiuj|Folio=1v,1v|Paragraph=5,5|Line=23,24|Norm=conitotihui|Analysed=Yes']
# ['49', ',', ',', 'PUNCT', '_', '', '51', 'punct', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=,|Analysed=Yes']
# ['50', 'in', 'in', 'DET|SCONJ', '_', '_', '51', '_', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=in']
# ['51', 'techcauhtiuj', 'cahua', 'VERB', '_', 'Number[obj]=Plur|Number[subj]=Plur,Sing|Person[obj]=1|Person[subj]=3|Purpose=And|Subcat=Tran|Tense=Pres|VerbForm=Fin', '48', '_', '_', 'Orig=tech·cauh·tiuj|Folio=1v,1v,1v|Paragraph=5,5,5|Line=24,24,24|Norm=techcauhtihui|Analysed=Yes']
# ['52', ',', ',', 'PUNCT', '_', '', '54', 'punct', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=,|Analysed=Yes']
# ['53', 'in', 'in', 'DET|SCONJ', '_', '_', '54', '_', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=in']
# ['54', 'vevetque', 'huehuetque', 'NOUN', '_', 'Number=Plur', '48', 'nsubj', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=huehuetque|Gloss=viejos|Analysed=Yes']
# ['55', ':', ':', 'PUNCT', '_', '', '56', 'punct', '_', 'Folio=1v|Paragraph=5|Line=24|Norm=:|Analysed=Yes']
# ['56', 'ca', 'cah|ca', 'VERB', '_', '_', '1', '_', '_', 'Orig=caujctli|Folio=1v|Paragraph=5|Line=25|Norm=ca|AmbigNorm=True|Override=False']
# ['57', 'ujctli', 'huictli', 'NOUN', '_', 'State=Abs', '56', '_', '_', 'Orig=caujctli|Folio=1v|Paragraph=5|Line=25|Norm=huictli|Gloss=luma|Analysed=Yes']
# ['58', ',', ',', 'PUNCT', '_', '', '59', 'punct', '_', 'Folio=1v|Paragraph=5|Line=25|Norm=,|Analysed=Yes']
# ['59', 'mecapalli', 'mecapalli', 'NOUN', '_', 'State=Abs', '57', '_', '_', 'Folio=1v|Paragraph=5|Line=25|Norm=mecapalli|Analysed=Yes']
# ['60', ',', ',', 'PUNCT', '_', '', '61', 'punct', '_', 'Folio=1v|Paragraph=5|Line=25|Norm=,|Analysed=Yes']
# ['61', 'icnoiotl', 'icnoyotl', 'NOUN', '_', 'State=Abs', '57', '_', '_', 'Orig=ic·noiotl|Folio=1v,1v|Paragraph=5,5|Line=25,25|Norm=icnoyotl|Gloss=pobreza|Analysed=Yes']
# ['62', ',', ',', 'PUNCT', '_', '', '63', 'punct', '_', 'Folio=1v|Paragraph=5|Line=25|Norm=,|Analysed=Yes']
# ['63', 'qujtemouja', 'temohuia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '57', '_', '_', 'Orig=quj·temouja|Folio=1v,1v|Paragraph=5,5|Line=25,25|Norm=quitemohuia|Analysed=Yes']
# ['64', ':', ':', 'PUNCT', '_', '', '69', 'punct', '_', 'Folio=1v|Paragraph=5|Line=25|Norm=:|Analysed=Yes']
# ['65', 'ioan', 'huan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '69', '_', '_', 'Folio=1v|Paragraph=5|Line=26|Norm=ihuan|Gloss=con|Analysed=Yes']
# ['66', 'anoce', 'anoce', 'CCONJ', '_', '_', '69', '_', '_', 'Folio=1v|Paragraph=5|Line=26|Norm=anoce']
# ['67', ',', ',', 'PUNCT', '_', '', '69', 'punct', '_', 'Folio=1v|Paragraph=5|Line=26|Norm=,|Analysed=Yes']
# ['68', 'ie', 'ye', 'ADV', '_', '_', '69', '_', '_', 'Orig=ieixqujch|Folio=1v|Paragraph=5|Line=26|Norm=ye|AmbigNorm=True|Override=False']
# ['69', 'ixqujch', 'ixquich', 'PRON', '_', '_', '1', '_', '_', 'Orig=ieixqujch|Folio=1v|Paragraph=5|Line=26|Norm=ixquich|Gloss=todo']
# ['70', ':', ':', 'PUNCT', '_', '', '72', 'punct', '_', 'Folio=1v|Paragraph=5|Line=26|Norm=:|Analysed=Yes']
# ['71', 'aco', 'azo', 'ADV', '_', '', '72', '_', '_', 'Orig=acotitlatlatzi·ujti|Folio=1v,1v|Paragraph=5,5|Line=26,26|Norm=azo|Gloss=quizás|Analysed=Yes']
# ['72', 'titlatlatziujti', 'tlatzihuitia', 'VERB', '_', 'Animacy[obj]=Nhum|Number[subj]=Sing|Person[obj]=3|Person[subj]=2|Subcat=Tran|Tense=Past|VerbForm=Fin', '1', '_', '_', 'Orig=acotitlatlatzi·ujti|Folio=1v,1v|Paragraph=5,5|Line=26,26|Norm=titlatlatzihuiti|Analysed=Yes']
# ['73', ',', ',', 'PUNCT', '_', '', '80', 'punct', '_', 'Folio=1v|Paragraph=5|Line=26|Norm=,|Analysed=Yes']
# ['74', 'aco', 'azo', 'ADV', '_', '', '80', '_', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=azo|Gloss=quizás|Analysed=Yes']
# ['75', 'ie', 'ye', 'ADV', '_', '_', '80', '_', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=ye|AmbigNorm=True|Override=False']
# ['76', 'muztla', 'moztla', 'ADV', '_', '', '_', '_', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=moztla|Gloss=mañana|Analysed=Yes']
# ['77', ',', ',', 'PUNCT', '_', '', '78', 'punct', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=,|Analysed=Yes']
# ['78', 'viptla', 'huiptla', 'ADV', '_', '', '76', '_', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=huiptla|Gloss=pasado.mañana|Analysed=Yes']
# ['79', ',', ',', 'PUNCT', '_', '', '80', 'punct', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=,|Analysed=Yes']
# ['80', 'mocomaz', 'zoma', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Reflex[obj]=Yes|Subcat=Tran|Tense=Fut|VerbForm=Fin', '1', '_', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=mozomaz|Analysed=Yes']
# ['81', ',', ',', 'PUNCT', '_', '', '82', 'punct', '_', 'Folio=1v|Paragraph=5|Line=27|Norm=,|Analysed=Yes']
# ['82', 'monenequjz', 'nenequi', 'VERB', '_', '_', '80', '_', '_', 'Orig=mone¶·nequjz|Folio=1v,1v|Paragraph=5,5|Line=27,28|Norm=monenequiz']
# ['83', ',', ',', 'PUNCT', '_', '', '85', 'punct', '_', 'Folio=1v|Paragraph=5|Line=28|Norm=,|Analysed=Yes']
# ['84', 'in', 'in', 'DET|SCONJ', '_', '_', '85', '_', '_', 'Orig=injpalnemoanj|Folio=1v|Paragraph=5|Line=28|Norm=in']
# ['85', 'jpalnemoanj', 'Ipalnemohuani', 'PROPN', '_', '', '88', '_', '_', 'Orig=injpalnemoanj|Folio=1v|Paragraph=5|Line=28|Norm=ipalnemohuani|Analysed=Yes']
# ['86', ':', ':', 'PUNCT', '_', '', '88', 'punct', '_', 'Folio=1v|Paragraph=5|Line=28|Norm=:|Analysed=Yes']
# ['87', 'ma', 'ma', 'ADV', '_', '_', '88', '_', '_', 'Orig=maxicmotlatol¶·chieli|Folio=1v,1v|Paragraph=5,5|Line=28,29|Norm=ma|Gloss=OPT']
# ['88', 'xicmotlatolchieli', 'chiyelia', 'VERB', '_', 'Mood=Imp|Number[obj]=Sing|Number[subj]=Sing|Person[obj]=3|Person[subj]=2|Reflex[iobj]=Yes|Subcat=Ditr|VerbForm=Fin', '1', '_', '_', 'Orig=maxicmotlatol¶·chieli|Folio=1v,1v|Paragraph=5,5|Line=28,29|Norm=xicmotlahtolchiyeli|Gloss=espera.el.orden|Analysed=Yes']
# ['88.1', 'tlahtol', 'tlahtolli', 'NOUN', '_', '_', '_', '_', '_', 'Incorporated=Yes']
# ['89', ',', ',', 'PUNCT', '_', '', '90', 'punct', '_', 'Folio=1v|Paragraph=5|Line=29|Norm=,|Analysed=Yes']
# ['90', 'ca', 'cah|ca', 'VERB', '_', '_', '1', '_', '_', 'Folio=1v|Paragraph=5|Line=29|Norm=ca|AmbigNorm=True|Override=False']
# ['91', 'iuh', 'iuh', 'ADV', '_', '', '92', '_', '_', 'Folio=1v|Paragraph=5|Line=29|Norm=iuh|Gloss=así|Analysed=Yes']
# ['92', 'machiotica', 'machiotia', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr', '90', '_', '_', 'Orig=machiotica|Folio=1v|Paragraph=5|Line=29|Norm=machiotica|Analysed=Yes']
# ['93', ',', ',', 'PUNCT', '_', '', '95', 'punct', '_', 'Folio=1v|Paragraph=5|Line=29|Norm=,|Analysed=Yes']
# ['94', 'in', 'in', 'DET|SCONJ', '_', '_', '95', '_', '_', 'Folio=1v|Paragraph=5|Line=29|Norm=in']
# ['95', 'tonalamapan', 'tonalamapan', 'NOUN', '_', 'NounClass=Loc', '92', '_', '_', 'Orig=tonal·ama¶·pan|Folio=1v,1v,1v|Paragraph=5,5,5|Line=29,29,30|Norm=tonalamapan|Locative=Yes|Split=tonal·ama·pan|Gloss=en.el.calendario|Analysed=Yes']
# ['96', ':', ':', 'PUNCT', '_', '', '99', 'punct', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=:|Analysed=Yes']
# ['97', 'in', 'in', 'DET|SCONJ', '_', '_', '99', '_', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=in']
# ['98', 'vncan', 'oncan', 'ADV', '_', '', '99', '_', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=oncan|Gloss=aquí|Analysed=Yes']
# ['99', 'tictlapielia', 'pialia', 'VERB', '_', '_', '95', '_', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=tictlapiyelia']
# ['100', ',', ',', 'PUNCT', '_', '', '102', 'punct', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=,|Analysed=Yes']
# ['101', 'in', 'in', 'DET|SCONJ', '_', '_', '102', '_', '_', 'Folio=1v|Paragraph=5|Line=30|Norm=in']
# ['102', 'cujtlapilli', 'cuitlapilli', 'NOUN', '_', 'State=Abs', '99', '_', '_', 'Orig=cujtlapil¶·li|Folio=1v,1v|Paragraph=5,5|Line=30,31|Norm=cuitlapilli|Analysed=Yes']
# ['103', ',', ',', 'PUNCT', '_', '', '104', 'punct', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=,|Analysed=Yes']
# ['104', 'atlapalli', 'atlapalli', 'NOUN', '_', 'State=Abs', '102', '_', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=atlapalli|Analysed=Yes']
# ['105', ':', ':', 'PUNCT', '_', '', '109', 'punct', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=:|Analysed=Yes']
# ['106', 'cujx', 'cuix', 'ADV', '_', '', '109', '_', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=cuix|Gloss=quizás|Analysed=Yes']
# ['107', 'çan', 'zan', 'ADV', '_', '', '109', '_', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=zan|Analysed=Yes']
# ['108', 'nel', 'nel', 'ADV', '_', '_', '109', '_', '_', 'Folio=1v|Paragraph=5|Line=31|Norm=nel|Gloss=ya']
# ...
# ['4', '.', '.', 'PUNCT', '_', '', '1', 'punct', '1:punct', 'Folio=13v|Paragraph=5|Line=1|Norm=.|Analysed=Yes']
# ['1', 'In', 'in', 'DET', '_', '_', '2', 'det', '2:det', 'Orig=I·nchiqujmoli|Folio=13v,13v|Paragraph=6,6|Line=1,1|Norm=In']
# ['2', 'chiqujmoli', 'chiquimoli', 'NOUN', '_', 'State=Abs', '6', 'nsubj', '6:nsubj', 'Orig=I·nchiqujmoli|Folio=13v,13v|Paragraph=6,6|Line=1,1|Norm=chiquimoli|Analysed=Yes']
# ['3', ',', ',', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=13v|Paragraph=6|Line=1|Norm=,|Analysed=Yes']
# ['4-5', 'cacentetl', '_', '_', '_', '_', '_', '_', '_', '_']
# ['4', 'ca', 'cah|ca', 'PART', '_', '_', '6', 'discourse', '6:discourse', 'Orig=cacentetl|Folio=13v|Paragraph=6|Line=1|Norm=ca']
# ['5', 'centetl', 'ce', 'NUM', '_', 'NounType=Clf', '6', 'nummod', '6:nummod', 'Orig=cacentetl|Folio=13v|Paragraph=6|Line=1|Norm=centetl|Gloss=una.pieza|Split=cen·tetl']
# ['6', 'tototl', 'tototl', 'NOUN', '_', 'State=Abs', '0', 'root', '0:root|10:nsubj', 'Orig=to·totl|Folio=13v,13v|Paragraph=6,6|Line=1,1|Norm=tototl|Gloss=pájaro|Analysed=Yes']
# ['7', ',', ',', 'PUNCT', '_', '', '8', 'punct', '8:punct', 'Folio=13v|Paragraph=6|Line=1|Norm=,|Analysed=Yes']
# ['8-9', 'iuhqujn', '_', '_', '_', '_', '_', '_', '_', '_']
# ['8', 'iuhquj', 'iuhqui', 'ADV', '_', '', '6', 'acl', '6:acl', 'Orig=iuh·qujn|Folio=13v,13v|Paragraph=6,6|Line=2,2|Norm=iuhqui|Gloss=así|Analysed=Yes']
# ['9', 'n', 'in', 'SCONJ', '_', '_', '10', 'mark', '10:mark', 'Orig=iuh·qujn|Folio=13v,13v|Paragraph=6,6|Line=2,2|Norm=in']
# ['10', 'quauhchochopitli', 'cuauhchochopitli', 'NOUN', '_', 'State=Abs', '8', 'xcomp', '8:xcomp', 'Orig=quauh·chochopitli|Folio=13v,13v|Paragraph=6,6|Line=2,2|Norm=cuauhchochopitli|Analysed=Yes']
# ['11', ':', ':', 'PUNCT', '_', '', '14', 'punct', '14:punct', 'Folio=13v|Paragraph=6|Line=2|Norm=:|Analysed=Yes']
# ['12', 'auh', 'auh', 'CCONJ', '_', '_', '14', 'cc', '14:cc', 'Folio=13v|Paragraph=6|Line=2|Norm=auh|Gloss=y']
# ['13', 'veca', 'huehca', 'ADV', '_', '', '14', 'advmod', '14:advmod', 'Folio=13v|Paragraph=6|Line=2|Norm=huehca|Gloss=lejos|Analysed=Yes']
# ['14', 'quauhtla', 'cuauhtla', 'NOUN', '_', '_', '6', 'conj', '6:conj', 'Folio=13v|Paragraph=6|Line=3|Norm=cuauhtla|Gloss=bosque']
# ['15', 'in', 'in', 'DET', '_', '_', '16', 'det', '16:det', 'Orig=injchan|Folio=13v|Paragraph=6|Line=3|Norm=in']
# ['16', 'jchan', 'chantli', 'NOUN', '_', 'Number[psor]=Sing|Person[psor]=3|State=Pos', '14', 'nsubj', '14:nsubj', 'Orig=injchan|Folio=13v|Paragraph=6|Line=3|Norm=ichan|Gloss=su.casa|Analysed=Yes']
# ['17', '.', '.', 'PUNCT', '_', '', '6', 'punct', '6:punct', 'Folio=13v|Paragraph=6|Line=3|Norm=.|Analysed=Yes']
# ['1', 'Auh', 'auh', 'CCONJ', '_', '_', '7', 'cc', '7:cc', 'Folio=13v|Paragraph=6|Line=3|Norm=Auh|Gloss=y']
# ['2', 'in', 'in', 'SCONJ', '_', '_', '5', 'mark', '5:mark', 'Orig=injqc¶|Folio=13v|Paragraph=6|Line=3|Norm=in']
# ['3', 'jqc', 'ihcuac', 'ADV', '_', '_', '5', 'advmod', '5:advmod', 'Orig=injqc¶|Folio=13v|Paragraph=6|Line=3|Norm=ihcuac|Gloss=en.el.momento']
# ['4', 'tepan', 'pan', 'NOUN', '_', 'Animacy[psor]=Hum|NounType=Relat|Person[psor]=3|State=Pos', '5', 'obl', '5:obl', 'Folio=13v|Paragraph=6|Line=4|Norm=tepan|Analysed=Yes']
# ['5', 'tzatzia', 'tzatzia', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '7', 'advcl', '7:advcl', 'Folio=13v|Paragraph=6|Line=4|Norm=tzatzia|AmbigNorm=True|Override=False|Analysed=Yes']
# ['6', ',', ',', 'PUNCT', '_', '', '7', 'punct', '7:punct', 'Folio=13v|Paragraph=6|Line=4|Norm=,|Analysed=Yes']
# ['7', 'netetzaujloia', 'tetzahuia', 'VERB', '_', '_', '0', 'root', '0:root', 'Folio=13v|Paragraph=6|Line=4|Norm=netetzahuiloya']
# ['8', ':', ':', 'PUNCT', '_', '', '9', 'punct', '9:punct', 'Folio=13v|Paragraph=6|Line=4|Norm=:|Analysed=Yes']
# ['9', 'qujtovaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '7', 'parataxis', '7:parataxis', 'Orig=quj¶·tovaia|Folio=13v,14r|Paragraph=6,1|Line=4,1|Norm=quitoaya|Analysed=Yes']
# ['10', ',', ',', 'PUNCT', '_', '', '13', 'punct', '13:punct', 'Folio=14r|Paragraph=1|Line=1|Norm=,|Analysed=Yes']
# ['11', 'ca', 'ca', 'PART', '_', '_', '13', 'discourse', '13:discourse', 'Folio=14r|Paragraph=1|Line=1|Norm=ca|AmbigNorm=True|Override=False']
# ['12', 'amo', 'amo', 'ADV', '_', '', '13', 'advmod', '13:advmod', 'Folio=14r|Paragraph=1|Line=1|Norm=amo|Gloss=no|Analysed=Yes']
# ['13', 'qualcan', 'cualcan', 'ADV', '_', '_', '9', 'parataxis:speech', '9:parataxis:speech', 'Folio=14r|Paragraph=1|Line=1|Norm=cualcan|Gloss=a.buena.hora']
# ['14', ',', ',', 'PUNCT', '_', '', '16', 'punct', '16:punct', 'Folio=14r|Paragraph=1|Line=1|Norm=,|Analysed=Yes']
# ['15', 'in', 'in', 'SCONJ', '_', '_', '16', 'mark', '16:mark', 'Orig=inotioal¶·laque|Folio=14r,14r|Paragraph=1,1|Line=1,2|Norm=in']
# ['16', 'otioallaque', 'hualla', 'VERB', '_', 'Aspect=Prior|Number[subj]=Plur|Person[subj]=1|Subcat=Intr', '13', 'csubj', '13:csubj', 'Orig=inotioal¶·laque|Folio=14r,14r|Paragraph=1,1|Line=1,2|Norm=otihuallaque|Analysed=Yes']
# ['17', ':', ':', 'PUNCT', '_', '', '21', 'punct', '21:punct', 'Folio=14r|Paragraph=1|Line=2|Norm=:|Analysed=Yes']
# ['18', 'ca', 'ca', 'PART', '_', '_', '21', 'discourse', '21:discourse', 'Folio=14r|Paragraph=1|Line=2|Norm=ca|AmbigNorm=True|Override=False']
# ['19', 'itla', 'tla', 'PRON', '_', '_', '20', 'nmod', '20:nmod', 'Folio=14r|Paragraph=1|Line=2|Norm=itla|AmbigNorm=True|Override=False|Gloss=algo']
# ['20', 'ipan', 'pan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '21', 'obl', '21:obl', 'Folio=14r|Paragraph=1|Line=2|Norm=ipan|Analysed=Yes']
# ['21', 'ticholozque', 'choloa', 'VERB', '_', 'Number[subj]=Plur|Person[subj]=1|Subcat=Intr|Tense=Fut|VerbForm=Fin', '9', 'parataxis:speech', '9:parataxis:speech', 'Folio=14r|Paragraph=1|Line=2|Norm=ticholozque|Analysed=Yes']
# ['22', '.', '.', 'PUNCT', '_', '', '7', 'punct', '7:punct', 'Folio=14r|Paragraph=1|Line=2|Norm=.|Analysed=Yes']
# ['1', 'Tetzaujtl', 'tetzahuitl', 'NOUN', '_', 'State=Abs', '0', 'root', '0:root', 'Folio=14r|Paragraph=2|Line=1|Norm=Tetzahuitl|Analysed=Yes']
# ['2', 'itechpa', 'techpa', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '1', 'nmod', '4:case', 'Folio=14r|Paragraph=2|Line=1|Norm=itechpa|Analysed=Yes']
# ['3', 'in', 'in', 'DET', '_', '_', '4', 'det', '4:det', 'Folio=14r|Paragraph=2|Line=1|Norm=in']
# ['4', 'coiutl', 'coyotl', 'NOUN', '_', 'State=Abs', '2', 'nmod', '1:nmod', 'Folio=14r|Paragraph=2|Line=1|Norm=coyotl|Gloss=coyote|Analysed=Yes']
# ['5', '.', '.', 'PUNCT', '_', '', '1', 'punct', '1:punct', 'Folio=14r|Paragraph=2|Line=1|Norm=.|Analysed=Yes']
# ['1', 'Qujtoaia', 'ihtoa', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Past|VerbForm=Fin', '0', 'root', '0:root', 'Orig=Quj·toaia|Folio=14r,14r|Paragraph=3,3|Line=1,1|Norm=Quihtoaya|Analysed=Yes']
# ['2', ',', ',', 'PUNCT', '_', '', '5', 'punct', '5:punct', 'Folio=14r|Paragraph=3|Line=1|Norm=,|Analysed=Yes']
# ['3', 'ca', 'cah|ca', 'PART', '_', '_', '5', 'discourse', '5:discourse', 'Folio=14r|Paragraph=3|Line=1|Norm=ca|AmbigNorm=True|Override=True']
# ['4', 'in', 'in', 'SCONJ', '_', '_', '5', 'mark', '5:mark', 'Orig=intezcatlipuca|Folio=14r|Paragraph=3|Line=1|Norm=in']
# ['5', 'tezcatlipuca', 'Tezcatlipoca', 'PROPN', '_', '', '1', 'parataxis:speech', '1:parataxis:speech', 'Orig=intezcatlipuca|Folio=14r|Paragraph=3|Line=1|Norm=Tezcatlipoca|Analysed=Yes']
# ['6', ':', ':', 'PUNCT', '_', '', '8', 'punct', '8:punct', 'Folio=14r|Paragraph=3|Line=1|Norm=:|Analysed=Yes']
# ['7', 'mjiecpa', 'miecpa', 'ADV', '_', '', '8', 'advmod', '8:advmod', 'Folio=14r|Paragraph=3|Line=2|Norm=miecpa|Temporal=Yes|Analysed=Yes']
# ['8', 'qujmonaoaltiaia', 'nahualtia', 'VERB', '_', 'Aspect=Imp|Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Reflex[iobj]=Yes|Subcat=Ditr|Tense=Past|VerbForm=Fin', '5', 'conj', '5:conj', 'Folio=14r|Paragraph=3|Line=2|Norm=quimonahualtiaya|Analysed=Yes']
# ['9', 'in', 'in', 'DET', '_', '_', '10', 'det', '10:det', 'Folio=14r|Paragraph=3|Line=2|Norm=in']
# ['10', 'Coiutl', 'coyotl', 'NOUN', '_', 'State=Abs', '8', 'iobj', '8:iobj', 'Orig=Co¶·iutl|Folio=14r,14r|Paragraph=3,3|Line=2,3|Norm=Coyotl|Gloss=coyote|Analysed=Yes']
# ['11', ':', ':', 'PUNCT', '_', '', '17', 'punct', '17:punct', 'Folio=14r|Paragraph=3|Line=3|Norm=:|Analysed=Yes']
# ['12', 'auh', 'auh', 'CCONJ', '_', '_', '17', 'cc', '17:cc', 'Folio=14r|Paragraph=3|Line=3|Norm=auh|Gloss=y']
# ['13', 'injn', 'inin', 'DET', '_', '_', '14', 'det', '14:det', 'Folio=14r|Paragraph=3|Line=3|Norm=inin']
# ['14', 'coiutl', 'coyotl', 'NOUN', '_', 'State=Abs', '17', 'nsubj', '17:nsubj', 'Folio=14r|Paragraph=3|Line=3|Norm=coyotl|Gloss=coyote|Analysed=Yes']
# ['15', ',', ',', 'PUNCT', '_', '', '17', 'punct', '17:punct', 'Folio=14r|Paragraph=3|Line=3|Norm=,|Analysed=Yes']
# ['16', 'mjiecpa', 'miecpa', 'ADV', '_', '', '17', 'advmod', '17:advmod', 'Orig=mj·iecpa¶|Folio=14r,14r|Paragraph=3,3|Line=3,3|Norm=miecpa|Temporal=Yes|Analysed=Yes']
# ['17', 'teiaiacatzacujlia', 'yahyacatzacuilia', 'VERB', '_', 'Animacy[iobj]=Hum|Number[subj]=Plur,Sing|Person[iobj]=3|Person[subj]=3|Subcat=Ditr|Tense=Pres|VerbForm=Fin', '5', 'conj', '5:conj', 'Folio=14r|Paragraph=3|Line=4|Norm=teyayacatzacuilia|Analysed=Yes']
# ['18', 'in', 'in', 'DET', '_', '_', '19', 'det', '19:det', 'Folio=14r|Paragraph=3|Line=4|Norm=in']
# ['19', 'vtlica', 'ohtlica', 'ADV', '_', '', '17', 'obl', '17:obl', 'Folio=14r|Paragraph=3|Line=4|Norm=ohtlica|Gloss=en.el.camino|Root=ohtli|Analysed=Yes']
# ['20', '.', '.', 'PUNCT', '_', '', '1', 'punct', '1:punct', 'Folio=14r|Paragraph=3|Line=4|Norm=.|Analysed=Yes']
# ['1', 'Auh', 'auh', 'CCONJ', '_', '_', '10', '_', '_', 'Folio=14r|Paragraph=3|Line=4|Norm=Auh|Gloss=y']
# ['2', 'in', 'in', 'DET|SCONJ', '_', '_', '10', '_', '_', 'Orig=inj·quac|Folio=14r,14r|Paragraph=3,3|Line=5,5|Norm=in']
# ['3', 'jquac', 'ihcuac', 'ADV', '_', '_', '5', 'mark', '_', 'Orig=inj·quac|Folio=14r,14r|Paragraph=3,3|Line=5,5|Norm=ihcuac|Gloss=en.el.momento']
# ['4', 'iuh', 'iuh', 'ADV', '_', '', '5', 'advmod', '_', 'Folio=14r|Paragraph=3|Line=5|Norm=iuh|Gloss=así|Analysed=Yes']
# ['5', 'qujchioa', 'chihua', 'VERB', '_', 'Subcat=Tran', '10', 'advcl', '_', 'Folio=14r|Paragraph=3|Line=5|Norm=quichihua']
# ['6', 'y', 'y', 'CCONJ', '_', '_', '10', 'cc', '_', 'Folio=14r|Paragraph=3|Line=5|Norm=y|AmbigNorm=True|Override=False']
# ['7', ',', ',', 'PUNCT', '_', '', '10', 'punct', '_', 'Folio=14r|Paragraph=3|Line=5|Norm=,|Analysed=Yes']
# ['8', 'njman', 'niman', 'ADV', '_', '', '10', 'advmod', '_', 'Folio=14r|Paragraph=3|Line=5|Norm=niman|Analysed=Yes']
# ['9', 'ic', 'ic', 'ADV', '_', '_', '10', 'advmod', '_', 'Orig=icmocaquj|Folio=14r|Paragraph=3|Line=6|Norm=ic']
# ['10', 'mocaquj', 'caqui', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Reflex[obj]=Yes|Subcat=Tran|Tense=Pres|VerbForm=Fin', '0', 'root', '_', 'Orig=icmocaquj|Folio=14r|Paragraph=3|Line=6|Norm=mocaqui|Analysed=Yes']
# ['11', ',', ',', 'PUNCT', '_', '', '10', 'punct', '_', 'Folio=14r|Paragraph=3|Line=6|Norm=,|Analysed=Yes']
# ['12', 'ca', 'cah|ca', 'VERB', '_', '_', '14', '_', '_', 'Folio=14r|Paragraph=3|Line=6|Norm=ca|AmbigNorm=True|Override=False']
# ['13', 'amo', 'amo', 'ADV', '_', '', '14', 'advmod', '_', 'Folio=14r|Paragraph=3|Line=6|Norm=amo|Gloss=no|Analysed=Yes']
# ['14', 'qualcan', 'cualcan', 'ADV', '_', '_', '10', 'csubj', '_', 'Folio=14r|Paragraph=3|Line=6|Norm=cualcan|Gloss=a.buena.hora']
# ['15', 'in', 'in', 'SCONJ', '_', '_', '16', 'mark', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=in']
# ['16', 'viloa', 'huiloa', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '14', 'csubj', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=huiloa|Analysed=Yes']
# ['17', ':', ':', 'PUNCT', '_', '', '19', 'punct', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=:|Analysed=Yes']
# ['18', 'aco', 'azo', 'ADV', '_', '', '19', 'advmod', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=azo|Gloss=quizás|Analysed=Yes']
# ['19', 'ichtecque', 'ichtecqui', 'NOUN', '_', '_', '25', 'nsubj', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=ichtecque|Gloss=ladrones']
# ['20', ',', ',', 'PUNCT', '_', '', '19', 'punct', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=,|Analysed=Yes']
# ['21', 'anoço', 'anozo', 'ADV', '_', '_', '22', 'cc', '_', 'Folio=14r|Paragraph=3|Line=7|Norm=anozo']
# ['22', 'tetlatlacaltique', 'tetlatlazaltiqui', 'NOUN', '_', '_', '19', 'conj', '_', 'Folio=14r|Paragraph=3|Line=8|Norm=tetlatlazaltique|Gloss=robadores']
# ['23', ',', ',', 'PUNCT', '_', '', '25', 'punct', '_', 'Folio=14r|Paragraph=3|Line=8|Norm=,|Analysed=Yes']
# ['24', 'cana', 'cana', 'ADV', '_', '_', '25', 'advmod', '_', 'Folio=14r|Paragraph=3|Line=8|Norm=cana|Gloss=alguna.parte']
# ['25', 'vtlica', 'ohtlica', 'ADV', '_', '', '16', 'parataxis', '_', 'Folio=14r|Paragraph=3|Line=8|Norm=ohtlica|Gloss=en.el.camino|Root=ohtli|Analysed=Yes']
# ['26', 'cate', 'catqui', 'AUX', '_', '_', '25', 'cop', '_', 'Folio=14r|Paragraph=3|Line=9|Norm=cateh']
# ['27', ':', ':', 'PUNCT', '_', '', '25', 'punct', '_', 'Folio=14r|Paragraph=3|Line=9|Norm=:|Analysed=Yes']
# ['28', 'anoço', 'anozo', 'ADV', '_', '_', '31', 'cc', '_', 'Folio=14r|Paragraph=3|Line=9|Norm=anozo']
# ['29', 'itla', 'tla', 'PRON', '_', '_', '31', 'nsubj', '_', 'Folio=14r|Paragraph=3|Line=9|Norm=itla|AmbigNorm=True|Override=False|Gloss=algo']
# ['30', 'ipan', 'pan', 'NOUN', '_', 'NounType=Relat|Number[psor]=Sing|Person[psor]=3|State=Pos', '31', 'obl', '_', 'Folio=14r|Paragraph=3|Line=9|Norm=ipan|Analysed=Yes']
# ['31', 'chololoatiuh', 'chololoa', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Purpose=And|Subcat=Intr|Tense=Pres|VerbForm=Fin', '25', 'conj', '_', 'Orig=chololo¶·atiuh|Folio=14r,14r|Paragraph=3,3|Line=9,10|Norm=chololoatiuh|Analysed=Yes']
# ['32', ',', ',', 'PUNCT', '_', '', '_', '_', '_', 'Folio=14r|Paragraph=3|Line=10|Norm=,|Analysed=Yes']
# ['33', 'in', 'in', 'DET|SCONJ', '_', '_', '34', '_', '_', 'Folio=14r|Paragraph=3|Line=10|Norm=in']
# ['34', 'tecoco', 'tecoco', 'NOUN', '_', '_', '31', 'conj', '_', 'Folio=14r|Paragraph=3|Line=10|Norm=tecoco']
# ['35', '.', '.', 'PUNCT', '_', '', '31', 'punct', '_', 'Folio=14r|Paragraph=3|Line=10|Norm=.|Analysed=Yes']
# ['1', 'Nican', 'nican', 'ADV', '_', '', '2', 'advmod', '2:advmod', 'Folio=14r|Paragraph=4|Line=1|Norm=Nican|Gloss=aquí|Analysed=Yes']
# ['2', 'tzonqujca', 'tzonquiza', 'VERB', '_', 'Number[subj]=Plur,Sing|Person[subj]=3|Subcat=Intr|Tense=Pres|VerbForm=Fin', '0', 'root', '0:root', 'Folio=14r|Paragraph=4|Line=1|Norm=tzonquiza|Analysed=Yes']
# ['3', 'yn', 'in', 'DET', '_', '_', '4', 'det', '4:det', 'Folio=14r|Paragraph=4|Line=1|Norm=in']
# ['4', 'tetzavitl', 'tetzahuitl', 'NOUN', '_', 'State=Abs', '2', 'nsubj', '2:nsubj', 'Orig=tetza¶·vitl|Folio=14r,14r|Paragraph=4,4|Line=1,2|Norm=tetzahuitl|Analysed=Yes']
# ['5', ';', ';', 'PUNCT', '_', '', '7', 'punct', '7:punct', 'Folio=14r|Paragraph=4|Line=2|Norm=;|Analysed=Yes']
# ['6', 'yn', 'in', 'SCONJ', '_', '_', '7', 'mark', '7:mark', 'Folio=14r|Paragraph=4|Line=2|Norm=in']
# ['7', 'qujtetzammatia', 'tetzammatia', 'VERB', '_', 'Number[obj]=Sing|Number[subj]=Plur,Sing|Person[obj]=3|Person[subj]=3|Subcat=Tran|Tense=Pres|VerbForm=Fin', '4', 'acl', '4:acl', 'Orig=qujtetzam·matia|Folio=14r,14r|Paragraph=4,4|Line=2,2|Norm=quitetzammatia|Analysed=Yes']
# ['8', ',', ',', 'PUNCT', '_', '', '12', 'punct', '12:punct', 'Folio=14r|Paragraph=4|Line=2|Norm=,|Analysed=Yes']
# ['9', 'njçan', 'nican', 'ADV', '_', '', '12', 'advmod', '12:advmod', 'Orig=nj·çan|Folio=14r,14r|Paragraph=4,4|Line=3,3|Norm=nican|Gloss=aquí|Analysed=Yes']
# ['10', 'nueua', 'nueva', 'ADJ', '_', '', '9', 'obl', '9:obl', 'Folio=14r|Paragraph=4|Line=3|Norm=Nueva|Analysed=Yes']
# ['11', 'españa', 'España', 'PROPN', '_', '', '10', 'flat', '10:flat', 'Folio=14r|Paragraph=4|Line=3|Norm=España|Analysed=Yes']
# ['12', 'tlaca', 'tlacatl', 'NOUN', '_', 'Number=Plur', '7', 'nsubj', '7:nsubj', 'Folio=14r|Paragraph=4|Line=3|Norm=tlacah|Analysed=Yes']
# ['13', '.', '.', 'PUNCT', '_', '', '2', 'punct', '2:punct', 'Folio=14r|Paragraph=4|Line=3|Norm=.|Analysed=Yes']

# %%
import pickle
with open(f'ref_map_org.pkl', 'rb') as pickle_file:
        ref_map = pickle.load(pickle_file)
        
import pickle
with open(f'ref_map_norm.pkl', 'rb') as pickle_file:
        norm_map = pickle.load(pickle_file)
    
    
ref_map2 = {}
norm_map2 = {}

punct = [':',',',';','.']

for k in range(3,29):
    ref_map2[k] = []
    
for k in range(3,29):
    norm_map2[k] = []

for k in range(3,29):
    for i in range(len(ref_map[k])-1):
        
        x1 = ref_map[k][i]
        if len(ref_map2[k])>0:
            if ref_map2[k][-1][-1] == "-":
                x1 = "-"+x1
        tx1 = ref_map[k][i].split()
        x2 = ref_map[k][i+1]
        tx2 = ref_map[k][i+1].split()
        if len(tx1)>1:
            check = tx1[-1]
            check2 = tx2[0]
        
            if check not in orig_tokens and check2 not in orig_tokens and check[-1] not in punct:
                x1 = x1 + "-"
            
            ref_map2[k].append(x1)

        ref_map2[k].append(x2)
        
for k in range(3,29):
    for i in range(len(norm_map[k])-1):
        x1 = norm_map[k][i]
        if len(norm_map2[k])>0:
            if norm_map2[k][-1][-1] == "-":
                x1 = "-"+x1
        tx1 = norm_map[k][i].split()
        x2 = norm_map[k][i+1]
        tx2 = norm_map[k][i+1].split()
        
        if len(tx1)>1:
            check = tx1[-1]
            check2 = tx2[0]
            
            

            if check not in norm_tokens and check2 not in norm_tokens and check[-1] not in punct:
                x1 = x1 + "-"
                
            norm_map2[k].append(x1)
        
        norm_map2[k].append(x2)

# %%
norm_map2
# Out:
# {3: ['tenehua: in#tetzahuitl catca, in#quite',
#   'tzammatia, in yehhuantin mexica.',
#   'Ic ce capítulo, oncan mihtoa, in#te',
#   'tzahuitl in#quitetzammatia: in#ihcuac',
#   'yohualtica, aca quicaquiya: in chocaya:',
#   'itla tecuani, in#anoce, iuhqui aca',
#   'ilama#chocaya: auh yequene, in#tlein',
#   'quihtoaya, tonalpouhque: in mihtoa',
#   'ya tlamatinime catca.',
#   'In#ye#huecauh, in#oc tlateo',
#   'toco: in#iuh quihtoa, ce',
#   'quintin huehuetque, hu',
#   'ehuetlaca: in#oc titixca',
#   'huitoque, in#oc titomattoque, in#oc to',
#   'tlalpan tiquihtoaya: in#ayaque tech',
#   'nelotoque: in#ayaque totlah onoque.',
#   'Izquitlamanti, in#y, in quitetzammat',
#   'ia, in#quitetzahuittaya, in tetzahuitl ipan',
#   'quimatia in#netetzahuiloya, in tlatetza',
#   'huiaya.',
#   'Inic centlamantli, yehhuatl, in#ihcuac',
#   'aca quicaquiya: in tecuani choca, te',
#   'cuani ipan choca: in#iuhqui tecciztli',
#   'quipitza: tepetl quinanquilia: tec',
#   'uyoa, tlahualania: iuhquin ilama',
#   'pol choca. Inin, quitoaya ye yaomi',
#   'quiz: anozo ye miquiz, tlalmiquiz:',
#   'anozo, ye itla commonamictiz, ic'],
#  4: ['tiz: anozo ipilhuan cemeh quinmonam',
#   'aquiliz, quintlanamictiz: quintlatlacol',
#   'namictiz, icnoyotl calaquiz, in#inextitlan,',
#   'in#itlecuillan: atl nehneciz in#ichan. In#ihcuac',
#   'oyouh ipan mochiuh, in#y: niman ic yauh,',
#   'quittaz in#tonalpouhqui: ompa quella',
#   'cuahua, quitlahpaloa: quilhuia. Timotoli',
#   'nia xole, xolotze, telpochtle, tiacahue:',
#   'ca#nel tictemoa, tiquitlani, in mellacua',
#   'hualoca: ca#za ic otihualla, in#timotezcahuico,',
#   'in#timamoxhuico: xicchiye, in#tlein oticmo',
#   'macehui: ca#za amo ihuiyan cualli: amo tla',
#   'cayectli, amo tlacacemelle: ca#iuh co',
#   'nitotihui, in techcauhtihui, in huehuetque:',
#   'ca#huictli, mecapalli, icnoyotl, quitemohuia:',
#   'ihuan anoce, ye#ixquich: azo#titlatlatzihuiti,',
#   'azo ye moztla, huiptla, mozomaz, mone',
#   'nequiz, in#ipalnemohuani: ma#xicmotlahto',
#   'lchiyeli, ca#za iuh machiotica, in tonalamap',
#   'an: in oncan tictlapiyelia, in cuitlapil',
#   'li, atlapalli: cuix zan nel nimitziza',
#   'huiz, nimitzmamauhtiz?Ç ca#mopan o',
#   'quinec, in tlacatl totecuiyo: camo mo',
#   'tlacayocoya, in#tecuani: timotolinia, ca#za',
#   'nel iuhcan timotlacatili: ca#iuhca',
#   'motonal, in#amo#tlacacemellecan. Auh',
#   'injn, ca#oneltico: azo ye tocommahuizoz,',
#   'in#quenami momacehual: ma#ximella',
#   'cuahua, ma#titlaocox, ixquich motla',
#   'pal: oc motepitzyollo, oc mochoquiz,',
#   'motlaocol ipan xonye. Ca#ihzac, ca#za'],
#  5: ['ia, ic nimitzpantia, ic nimitzpayahu',
#   'alochtia: xitlamacehua, ma iciuhca onye',
#   'cauhtihuetzi, in#amatzintli: in#monextlah',
#   'ual, onmochihuaz: xoconmococohui, in izqui',
#   'tlamantli in amatl: in#copalli in olli etc.',
#   'Ihcuac, in, ticmattihui: ihzac tonalli, in#i',
#   'pan tictlamacazque, Tlalxictentica: in',
#   'mehuiltitica, tihualmohuicaz: nican nicno',
#   'mahuiz, niccencahuaz, nictlatlamantiliz,',
#   'in#ixquich monequiz: in#izquican icaz,',
#   'toteteuh, tonextlahual: ca#nehuatl,',
#   'nonoma nictlatitiuh, in mochan: nic',
#   'nomahuitiuh. Ihuin, in#quichihuaya, mo',
#   'tetzahuiani, motetzahui.Ç etc.',
#   'Ic ome capítulo, oncan mihtoa: in',
#   'tetzahuitl catca, in zan necoc tlachia',
#   'ya: in#iuhqui catca, in ihcuac quicaquiya,',
#   'in#tzatzia huactli: ihuan in#tlein quichih',
#   'uaya, pochteca in#ihcuac cana iuhqui o',
#   'htlica, in#inpan mochihuaya in#anozo in',
#   'pan tzatzia.',
#   'No ihuan, quitetzammatia: in#ihcu',
#   'aca ipan huehuetzca, huactli: in#iuh co',
#   'nihtoa, ome huitz quihtoa: in#quenman',
#   ', quenman amo cualli. In#ihcuac',
#   'cualli quinextia, ic quicaqui in#itlah',
#   'tol inic huehuetzca quihtoa: yeccan,',
#   'yeccan, in#ihcuac, in, amo netemma',
#   'cho: atle ic momauhtia, in nenenque:',
#   'zan ye papaqui: iuhquin#acohuetzi'],
#  6: ['pan ic#onyazque: azo itla ipan mo',
#   'pohuatihui: itla cualli, quicnopilhui',
#   'zque. Auh in ye#oquicacque, in#iuh',
#   'qui ommimictoc, ic huetzca, tlatlapi',
#   'tzahua: in#iuhqui, ixillan, iyomotlan,',
#   'oncuacuauhti: in#iuhqui, mocaca',
#   'nahua, paqui, huehuetzca: iuhquin on',
#   'tlanahui, iuhquin ocehuetzi, ayocac na',
#   'huati: ca#za tlatolihui, ca#za tlaquechpili',
#   'hui, ayocmo tenahuatili: ic quimatia,',
#   'azo itla ohui, inpan ye ommochihuaz:',
#   'itla ohui, ye conmonamictizque: anozo',
#   'cemeh aca ye miquiz: azo ye#huitz coco',
#   'liztli, anozo cana inpan, ye#hualmo',
#   'tzacuaz. In#inpan mochihua, in,',
#   'azo cana tepetzalan; atlauhitic,',
#   'ixtlahuatl itic, cuauhnepantla, cuauh',
#   'yocatlan, cuauhihtic, cuauhuitl itic:',
#   'auh intla#pochteca, oztomeca, nehn',
#   'emini: iuhqui inpan omochiuh, in#in',
#   'pan ohuehuetzcac huactli: quihtoaya.',
#   'Azo, ye itla, commonamictizque:',
#   'azo ye ontlaatoctizque: anozo ye',
#   'acame, tlahueliloque, inmac ye om',
#   'maquizque, ichtecque, tetlacui',
#   'cuilique, tetlatlazaltique, tetlana',
#   'mohuelique, inmac ye#ontlatlazazque,',
#   'quintlacuicuilizque, quintlacen'],
#  7: ['tlanamohuelizque: anozo cana ce',
#   'meh, ye oncuauhtenhuetzizque, ye on',
#   'huetzizque, ye ommomaiahuique:',
#   'noce, ye#ontecuancualozque, tecua',
#   'ntlacualtin, tecuanime intlacual',
#   'huan, ye ommochihuazque: anoce,',
#   'cana inpan ye#hualmotzacuaz yao',
#   'yotl: ye#conmonamictizque. In#ihcuac',
#   'in, in#aquintachcauh, in tach',
#   'cauhchiuhtiuh, in#tachcauh ica',
#   'tiuh ohtlipan, oncan pehua, in qui',
#   'mellacuahua, in quinchoquiztlap',
#   'aloa, iteiccahuan, itlahuapahua',
#   'lhuan: in ohtli ipan quimixtla',
#   'machtia, quimilhuia. Ximella',
#   'cuahuacan, nopilhuane, noteic',
#   'cahuane, quennel titotolinia: ma',
#   'caiac tlaocoya, nentlamati in#i',
#   'yollo, ca#nel ic#tihuallaque, in#timi',
#   'quico: ca#iuh hualyetia, iuh#quihua',
#   'lmattiya in#toyollo: inic ticualla',
#   'lcahuique, ticuallalotique in#ton',
#   'ca, in#teca: in#tahui, in#totla, in#tom',
#   'ach, in tohueltiuh: ca#ye inic',
#   'techchoquili, inic topan quipixo,',
#   'in#ichoquiz, in#itlaocol: azo cana'],
#  8: ['itic, cuahuitl itic, cecemmantoz',
#   'in tomiyo: in#totzon, nonoquiuh',
#   'toz, aalacatoz in#tezzo, in totlapallo:',
#   'ca#nel otomacehualtic, ma#cayacqui',
#   'cihuatlamachti in#iyollo: xicmotla',
#   'cuamacacan in miquiztli, xicmo',
#   'tlatlauhtilican in totecuiyo: ma#cayac',
#   'tle itic quinemiti, quilnamiqui: ma',
#   'ca#za quin#ic ticmatizque, in zazo tle',
#   'itech titotzontzonatihui: oncan ic#cem',
#   'mayan, tontochochoquilizque: ca#za',
#   'nel yehhuatl inic tiquinteyotico, ti',
#   'quimitauhcayotico, tiquintonaleh',
#   'uaco, tiquintzonteconacocuico in#',
#   'totechiuhcahuan, in#pochteca, in#yaq',
#   'ue: ca#yeppa iuh quimattihui, iuh',
#   'quimahuizotihui, camo quin tehhuan',
#   'ye toconnextizque, ic toco',
#   'nittazque, in#tlein topan mochih',
#   'uaz: ximellacuahuacan, nopilhua',
#   'ne. Auh intla#cana o#impan yoac,',
#   'cana cuauhuitl itzintlan, anozo a',
#   'tlauhcamac, ommololoa, onmoce',
#   'mololoa, ommotepeuhtitlalia, mo',
#   'nechicoa, quicuitlalpiya, quicen',
#   'cuitlalpiya, quicemilpiya, quicem',
#   'mana in#intopil, in#ipan#quixehuay'],
#  9: ['pan tlamacehua, mizo, monacazte',
#   'qui, tlacoquixtia, ca#za quimocem',
#   'macatoque, in#tlein inpan, ye om',
#   'mochihuaz: auh ayocac ontlama',
#   'ti, ayocac itlamatia, intla iuhqui',
#   'inpan mochihua, in#iuhqui ic o',
#   'quintetzahui huactli. Auh anoce',
#   'zan maquiza, acazo#tle inpan',
#   'mochihua: in oncan in nemauhti',
#   'aya, in#inmahuizcuiyan omochiuh',
#   'ca. Intla#catle inpan omochiuh,',
#   'ic oc#ceppa achitzin, hualmoyoli',
#   'zcalia: hualaquetza onmocuaaha',
#   'iohuia: ic ommotonallalilia, inic',
#   'intech huacca mahuiztli: auh in',
#   'mauhcatlaca teteiccahuan, in#amo',
#   'tonalchicahuaque, in#amo#tonalla',
#   'palihui, ca#za ye in quimattihui, in#qui',
#   'mamattihui: ayocmo paqui, ayocmo',
#   'tlatoa, ayocmo nahuati, ayoccan',
#   'ahuia in#iyollo: ca#za tlanauhtihui, in',
#   'nehnemi, ca#za imitic tlacuicuiloti',
#   'hui, in tleinmach quilnamiqui: a',
#   'yocmo ihuiyan, in#oc#nen',
#   'achi quitoca tlalli: ca#za ye in#qui',
#   'mati, azo quin#cana in ye commo',
#   'namictizque, in#tlein huel quihtoz#ne'],
#  10: ['motetzahuique. Ye omihto, tel ayac',
#   'quimati, in#azo huel neltiz: in#aca',
#   'nozomo, ca#za itlahtol itech moca',
#   'qui: inic ome huitz quihtoa, cualli,',
#   'ihuan amo cualli.',
#   'Ic eyi capítulo, oncan motene',
#   'hua: in#tetzahuitl catca, in#tetzam',
#   'machoya: in#ihcuac yohualtica qui',
#   'caquiya, in#iuhqui aca, tlatepozmi',
#   'huia: in#iuhqui cuauhxeloaya, in',
#   'quihtoaya, yohualtepoztli.',
#   'No ihuan, tetzahuitl catca, ne',
#   'tetzahuiloya, tetzammachoya: in#i',
#   'toca yohualtepoztli. Ihcuac caquiz',
#   'tiya, in#ohuellallimictimotecac: in#a',
#   'yocac nahuati. In#ontlamacehuato,',
#   'in#onacxoyatlalito tlamacazque:',
#   'in#intlamacehuayan tepeticpac, in#za',
#   'zo campa ye, onhuiya, inic moca',
#   'quiya, inic caquiztiya, iuhquin',
#   'aca, tlaxeloa, cuauhxeloa: cenca',
#   'huehca caquizti, cenca temamauh',
#   'ti, teyolmicti, tezotlauh. Inin,',
#   'yohualtepoztli, iuh mihtoa, quilmach'],
#  11: ['tlipoca: inic teca mocacayahuaya,',
#   'teca mahuiltiaya, quihtoa. In#aquin',
#   'quittaya, in mihihuintia, in#iyollo',
#   'quimatia , in#amo momauhtiani,',
#   'in tonallapalihui, huel ic momotla:',
#   'quimomaca, ayocmo quicahua, i',
#   'nic huel quittaz, quitlacanotzaz,',
#   'huel itech mopiloa, itech motla',
#   'paltilia, inic quitoca: quitepotzt',
#   'oca, quitlalochtoca, ipampa inic',
#   'huel cahciz: quittaz, in#quenami ite',
#   'tzauh: in#iuh conihtoa, in aquin huel',
#   'cahciya, in quittaya: ayaxcan in huel',
#   'itech pachihui: oc quitohtoca, nohuian',
#   'quinemitia: nohuian caaxitia. Ihcuac',
#   'in#oquiciammicti, cana ohtlica qui',
#   'hualmochiyeltia: auh in ye quitta in',
#   'ye quitzticac, iuhquin#tlacatl quech',
#   'cotonqui, quechcotoctic, quechte',
#   'poltic: ihuan elchiquiuhtlapanqui,',
#   'ellapanqui: in#iuh conihtoa: quilmach',
#   'yehhuatl, in caquizti, ielchiquiuh:',
#   'iuhquin#ommonamiqui onmocac',
#   'amapiqui, ommopipiqui, oncha',
#   'chacuani. Auh ye#yehhuatl, in, i'],
#  12: ['cazqui, in#anozo zan mihihuintia',
#   'in#yaotlahueliloc: in#ihcuac in#ohuel#c',
#   'acic, in#ohuel quittac, niman ye qui',
#   'mottilia in#iyollo: quicuitihuetzi, qui',
#   'tlalochana, quimotzoltzitzquia,',
#   'quicotonilia: ic#quitlaitlanilia, in',
#   'tlein quimacaz, in#tlein#quinemacti',
#   'z, in tlein quimacehualtiz, azo ne',
#   'cuiltonolli, azo tlamaliztli, azo o',
#   'quichyotl: anozo netoliniliztli, azo',
#   'huictli, azo mecapalli: iuh mihtoa,',
#   'ca#moch#ye quitemacehualtiaya,',
#   'itenamac mochihuaya. Auh in',
#   'tla#ye#quinotza, quilhuia: Tocniuhtze,',
#   'huitzitle, yaotle: tle#tinechilhuia, tle',
#   'tinechnequilia, xinechcahua: nimitz',
#   'macaz in#tlein ticnequi: huel niman',
#   'ic#tenotzaya, ic quitlacatocayotiaya,',
#   'in#aquintlein itoca, in#ipiltoca.',
#   'Auh quilhuia in macehualli, in#o',
#   'quimottiti: amo#nimitzcahuaz, ca#oni',
#   'mitzan. Ic oncan quilhuia, ihzac',
#   'ce huitztli: nimitzmaca, xinechcahua:',
#   'amo quicelia, amo quihuelitta, in#yol',
#   'lochicahuac: quinihcuac quicahua, in'],
#  13: ['ztli: ic quinextia, quinezcayotia, ca#za',
#   'tlamatiuh in#yaoc, amo nenquizaz:',
#   'izqui cahciz in#oquitenehuili, in#oqui',
#   'macac huitztli: ic moch oncan, qui',
#   'macehualtia in#tlalticpac paquiliz',
#   'tli, neyollaliliztli: in xochitl, in#i',
#   'yetl, in netlamachtilli: in#tilmatli,',
#   'in#tenzacatl, in#tlapiloni. Auh ihuan',
#   'mihtoa, iuhca in#nenonotzalli, in',
#   'tlatlatolli: in#aquinamo quitlatla',
#   'toltia, zan huel niman quicotoni',
#   'lia, quitlatzcotonilia in#iyollo: ix',
#   'pampa yehhua, motlaloa in#oquico',
#   'tonili iyollo: cana quitlatia, huel',
#   'quiquiquimiloa, quitepitzilacatzoa:',
#   'quinihcuac in#otlathuic quittac,',
#   'in quiteittitia, in#tlacualli, intla',
#   ': in conitta: iztac ihuitl in mo',
#   'lontica, anozo huitztli, azo ce, ano',
#   'zo ome, ic#quinextia ca#za cualli, in#i',
#   'macehual: omochiuh. Auh in',
#   'tlacamo cualli, in conitta: tecolli,',
#   'anozo tzotzomatli, ic quinextia,',
#   'in zan icnoyotl, netoliniliztli, o',
#   'quimacehualti. Auh in#aquin',
#   'amo cenca tonallapalihui, in#a'],
#  14: ['tlacatl: amo zan huel cana, zaniyo qui',
#   'caqui, zan icampa ontlacuecue',
#   'tlaxoa, ontlacuecuechcahua: amo',
#   'huel quitoca, zan onciammiqui, on',
#   'mociauhcanequi, mimiquiz in#ina',
#   'cayo, ca#za ohtlica chachapantiuh, a',
#   'yocmo huel nehnemi: ic quimati in',
#   'zan oquitetzahui yohualtepoztli, zan',
#   'ica onmocacayauh, ica ommahui',
#   'lti: azo cocoliztli, miquizliztli: anozo',
#   'icnoyotl, tlacoyotl, tlatlacolli, in#o',
#   'quimacac: inic oquimotlac.',
#   'Ic nahui capítulo, oncan mi',
#   'htoa: in#tetzahuitl inic motetzahui',
#   'aya, in#ihcuactecolotl chocaya.',
#   'No ihuan netetzahuiloya, tla',
#   'tetzahuiaya, tetzammachoya, in te',
#   'colotl choca: in#ihcuactla#aca i',
#   'tlapantenco, anozo ixacalticpac,',
#   'icuauhticpac chocatica: in quica',
#   'qui quihtotica: tecolo, o, o, tecoloo',
#   'o, ihuin in#caquizti, in#choca. Qui',
#   'htoa in#ihcuac in cacoya, quinextia'],
#  15: ['tzahuitl: in#aquinoquicac azo',
#   'ye#miquiz: azo tlacihuiti, azo tla',
#   'tlatzihuiti tlalmiquiz, anozo yao',
#   'miquiz, anoce aca ce ipiltzin',
#   'ye#miquiz, anozo itlacauh ye#cho',
#   'loz, azo ye#tlalpolihuiz in#ichan,',
#   'tlalli canahuaz, atl nehneciz, aca',
#   'huatimaniz in quiyahuatl, in ithu',
#   'alli, tepantli xixitintoz, tlahu',
#   'ihuitontoz, tlahuehuelontoz, oncan',
#   'nexixaloz, neaxixaloz, nema',
#   'nahuiloz, tlazollaxoz, tequixquitl',
#   'coxontoz, tlalli ipotocatoz:',
#   'ihcuac itoloz inic tlamahuizoloz: ic',
#   'ocatca in, ichan in oncan',
#   'ontlamamauhtico: in oncan on',
#   'moteiotico chane: mochipa otla',
#   'mahuizmamanca, otlatetzcaliuht',
#   'imanca: ma#cel cana ce tlazolli',
#   ': auh in#icaltech ayac',
#   'huel omaxixaya, teahuaya: auh i',
#   'n#axcan ye#za#iuhcan, za#tepan',
#   'tli yehuatoc.'],
#  16: ['htoa: in#tetzahuitl catca, in#itechpa chi',
#   'cuatli.',
#   'No ihuan netetzahuiloya, tetza',
#   'uhittoya, in#chicuatli: anozo chichtli',
#   'in#ihcuac aca, itlapanixcuac tzatzi: tza',
#   'tzitiquiza, in quihtoa: cuel, ic quinel',
#   'tocaya, ca#ye aca miquiz: ye#cemeh mi',
#   'quizque in chaneque: ye#cemeh cocoliz',
#   'cuizque. Auh intla#ye#oppa, ye#expa',
#   'tzatzitiquiza: in zan ye#oncan, in#tla',
#   'panixcuac, anozo in#calipan, ic cenca',
#   'momauhtia, motemmati: huel ic qui',
#   'neltocaya, ca#za amo zan tlanehuan: ca#za',
#   'huel neltiz, inic inpan otzatzic chicua',
#   'tli. No ihuan, intla ye aca mococoa: in#i',
#   'pan tzatzitiquiza, quihtoaya ca#za ayoc',
#   'mo quizaz: ca#ticcahuazque. Ipampa',
#   'iuh quihtoaya, quilmach, in yehhuatl chi',
#   'cuatli: intitlan, intlayohual, in mictlan',
#   'teuctli: ihuan mictecacihuatl: ommat#in',
#   'mictlan, ic#quitocayotiaya, yaotequihua:',
#   'ipampa ca#za inteancauh, intenotzcauh,',
#   'in mictlan teuctli: ihuan mictecacihuatl.',
#   'Auh in#ihcuac, quicaquiya tzatzi: ihuan',
#   'in mozticacalatza niman conahua,',
#   'conilhuia in toquich: ma#xitlamattiuh',
#   'nocne, tixtecocoyocpol: monan tic',
#   'yeco. Auh in#cihua conilhuia, inic'],
#  17: ['pol: cuix oticcoyoni in tzontli ic#natli',
#   'tiaz: ca#yamo cuel in#niyaz. Inic iuh',
#   'conahua in, quilmach#iuhquin ic#one',
#   'patilo, ic#queleltia, ic quilochtia, ic',
#   'quiyacatzacuilia, in#itenotzaliz: inic',
#   'amo inpan neltiz, ic#quintzatzilia.',
#   'Ic#chicuacen capítulo, oncan mi',
#   'htoa: in#tetzahuitl catca, inic motetzahu',
#   'iaya: in#ihcuac aca quittaya, cozamatl in',
#   'teixpan tlahuiltequiya.',
#   'No ihuan netetzahuiloya in coza',
#   'matl, anozo cozatli: in#ihcuac aca',
#   'ichan calaquiya: anozo ohtlica, cana qui',
#   'namiqui: quiyacahuiltequi, ixpan',
#   'tlaxtlapaloa: quihtoaya, azo ye itla',
#   'conmonamictiz tetolini: azo ye itla',
#   'ipan oncholoz, amo huel yaz in#campa',
#   'yaz#nequi: azo acame inmac huetzitiuh,',
#   'quimictizque: anozo ye#tlahtolli, itech#o',
#   'nehuaz: azo ye aca, tlahtolli conehualtiz:',
#   'contlahtollaquiliz, contlahtolchichih',
#   'uiliz. Auh in#ihcuacitto, netlacmauh',
#   'tilo: necuitihuecho, cecepoca, cuecue',
#   'yoca, in#tenacayo, ticecepoca, ticuecue',
#   'yoca, ticuacecepoca, titocuitihuetzi:',
#   'tetequipachoa, teyollitlacoa. Auh',
#   'in#iuhqui, ic mochichiuh: ixtecui'],
#  18: ['iuhquin mapipitzoa: tocuilehua, tocuile',
#   'choa: no#yaotequihua quitocayotiaya.',
#   'Ic chicome capítulo, oncan mihtoa:',
#   'in tetzahuitl inic motetzahuia, in#itechpa',
#   'tochin: in#ihcuac quittaya in ye#oncalaqui',
#   'ichan.',
#   'No ihuan, netetzahuiloya in#tochin:',
#   'in#ihcuacaca ichan calaquiya, quihtoa',
#   'in millaca, in milpan tlacah: ye#tlalpoli',
#   'huiz in#ichan. Anozo ye aca choloz, ye',
#   'in#tochtli, in mazatl ihui, ye',
#   ', ye mazatiz, ye motochtiliz, ye#mo',
#   'mazatiliz. Inic mochichiuh tochin,',
#   'nacazpapatlactic, tentipontic, tentete',
#   'pontic, eliztac: ihuan zan cuitlapiltete',
#   'pontic.',
#   'Ic chicueyi capítulo, oncan mihtoa:',
#   'in#tetzahuitl, inic motetzahuiaya: in#i',
#   'hcuac quittaya pinahuiztli.',
#   'No ihuan, netetzahuiloya in pinahui',
#   'ztli: iuhquin tocatl tlatlauhqui, tla',
#   'tlactic. In#ihcuac aca, ichan calaqui,',
#   'in quitta: anozo ohtlica quiyacanamiq',
#   'ui, quihtoa ye#huitz cocoliztli, anozo',
#   'ye itla conmonamictiz: azo ye aca',
#   'conahuaz, itla ic conpinauhtiz: auh',
#   'in#ihcuac, tla#oittoc techan: in#aquin',
#   'oquittac: niman ic conana, nauhcam'],
#  19: ['iuhquin cruz quiquechilia: auh ne',
#   'pantla iyolloco contlalia, oncan on',
#   'chicha: niman ye ic quitlatoltia,',
#   'quilhuia. Tlein#ic otihualla, tla#niquitt',
#   'a, tlacuele nocommahuizo: niman',
#   'ic quitztimotlalia, quitztica in cam',
#   'pa ye itztiyaz. Intla ye ompa itztiuh,',
#   'mictlampa: ic quimati ca#ye miquiz,',
#   'in#oquimottiti: auh intlacamo om',
#   'pa itztiuh, ic quimati, azo zan',
#   'itla in quihtoz#nequi, acazomo cen',
#   'ca hueixtica: quihtoaya in motetza',
#   'hui, tla#quiyocoli, tla#motelchihua, in',
#   'yoyoliton: cuix zan ye toconmatti',
#   'yezque?Ç cuix zan ye ipan tonyezque?Ç',
#   'ma#ca#quin#ic#ticmatizque in#tlein,',
#   'quihtoz#nequi. Niman ic conana:',
#   'omaxac concahua. Auh in aca zan',
#   'contzonhuia, azo compiloa: intla',
#   'ayocac quitta: in cenca huel',
#   'quitetzammati. Auh intla#zan ipan',
#   'otlathuic, in zan ye oncan pilcac, ic',
#   ': amo cenca quihueyimati,',
#   'atle ipan conitta. Auh inic contla',
#   'lia tlanepantla, chichitl, anozo oc',
#   'tli: mihtoa ic contlahuantia: ihuan'],
#  20: ['no#cualli quinextia, azo itla cualli te',
#   'macehual mochihua.',
#   'Ic chicnahui capítulo, oncan mi',
#   'htoa: in tetzahuitl in quimotetzahuiaya,',
#   'in#ihcuaccentetl yolqui, in cenca iyac,',
#   'in#itoca Epatl: in#ihcuacye oncalaqui',
#   'ichan, auh anozo in#ihcuac moxixa:',
#   'miyexi.',
#   'No ihuan in epatl, netetzahuiloya:',
#   'in#ihcuacaca ichan calaqui, anozo on',
#   'can mopilhuatia: quihtoa, ye#miquiz in',
#   'chane: ipampa iuh quitoaya, ca#za amo',
#   'inentlan, amo inemiyan in callan, in#techan:',
#   'ca#milpan, zacatlan, memetlan nono',
#   'pallan, in#inemiyan, in#iquizayan. No ipan',
#   'quimatia, ca#za ixiptla in tlacatecolotl,',
#   'Tezcatlipoca: auh in#ihcuacmiyexi, in',
#   'teiyexi, quihtoaya: omiyex in#Tezca',
#   'tlipoca. Auh intla aca canazne',
#   'qui, in#acequitoca: zan ic quiqueloa,',
#   'ic ica mocayahua: cenca quiquetza,',
#   'cacoquetza in#icuitlapil: auh quini',
#   'hcuac, intla#ye#huel itech#onaci: niman',
#   'ic quihualiyexi, iuhquin aca tlaalpichia,',
#   'huel neci, huel itto, in#iyel: iuhquin a',
#   'yauhcozamalotl, ic#moquetza: auh',
#   'huel temahua, tetechaqui in#iyel, ayax',
#   'can tecahua: ic huetzi, ic tlaxo, ic#tla'],
#  21: ['centlalli mani: nohuiyan aci, tepan mo',
#   'teca, inic iyac, inic tetlayelti: teyacaxo',
#   'locho. Auh quihtoa, in#ihcuacin#eco, mi',
#   'necui, ahuel onchicha: quilmach in',
#   'tla aca onchichaz, cuaztalihuiz, como',
#   'niz: ic cenca quintlacahualtia, in#tepilhuan:',
#   'inic amo onchichazque: in#ihcuacin#e',
#   'co yel: zan onmotempachoa.',
#   'Ic matlactli capítulo, oncan mi',
#   'htoa: in tetzahuitl inic motetzahuiaya,',
#   'in#intechpa azcame, anozo cuecueya:',
#   'ihuan in#quiquimichtin.',
#   'No ihuan, netetzahuiloya in#azcame,',
#   'in#tlatlauhque, anozo tliltique: in#ihcuac',
#   ', ichan moloni, mopotza: qui',
#   'nextiaya in#tecocoliliztli: quihtoaya',
#   'oittoque, azo aca totecoco',
#   'licauh itla otechtoquilico: iuh mi',
#   'htoa, iuh nemacho in#tlein quitetoq',
#   'uilia, tecocoliani: yehhuan in mo',
#   'cuepa azcame, ihcuac in ye huehcahua,',
#   'tlein oquitocaque: mochi yehhuan',
#   'intech tlami in tecocoliani, in te',
#   'miquitlanini, in temiquiztemachi',
#   'ani, in temiquiz, in',
#   'teveijecoanj , in#atlaca in#tlatlaca'],
#  22: ['quintoca, quintlalia in#azcame. In#ih',
#   'cuac aca ichan moloni, ic#quitetza',
#   'huia, ic quitlania in#imiquiz: in#a',
#   'quin tlacocoa, connectia, connequi',
#   'lia, connequiltia: in macuele miqui,',
#   'in macuel ompopolihui: inic tlacua',
#   'lania, inic tlayolquixtia, inic tlaa',
#   'mana, inic teyollo ixco icac, inic',
#   'tlatequipachoa, inic atetloc mone',
#   'qui. Za#ye#no#iuhqui, mochiuh',
#   'qui: quicenhuica, quicemihtoa in mi',
#   'quiztetzahuitl. In yehhuatl calcuiyatl,',
#   'azo cana tepancamac: calcuac in',
#   'quintlalia tecocoliani: cotaloa, co',
#   'talotica inic tlatoa. No iuhqui',
#   'in#tetzauhquimichin, anozo tetlaque',
#   'chililli.Ç Plʼ chililti: mochi yehhuan',
#   'quintlaliaya, quintetoquiliaya, in#a',
#   'tlaca, in#tecocoliani: inic zazo, inic mo',
#   'caqui: huel pipitzca, pipipitzca, pipitzca',
#   'ticate, inic tlatoa.',
#   'Ic matlactli oce capítulo, oncan',
#   'motenehua in#tetzahuitl: inic motetza',
#   'huiaya: in#ihcuacyohualtica, quimittaya',
#   'tlacahuiyaque, quinametli.'],
#  23: ['huiyac: in#ihcuac yohualtica moteittitia,',
#   'mihtoa: zan ye moche inahual, inecue',
#   'paliz in#tlacatecolotl Tezcatlipoca,',
#   'moch#ic teca mocayahua: in#ihcuacaca',
#   'iuh quimottitia, ye quitetzahuia in a',
#   'zo ye yaomiquiz, azo ye huicoz. Auh i',
#   'n#aquin huel mihihuintia, in#yollotla',
#   'palihui, in#tonalchicahuac, ayocmo qui',
#   'cahua, quiteteuhtzitzquia, itech mopi',
#   'loa: quitlanilia in huitztli, inic quite',
#   'molia oquichiotl, in#tlamaliztli.',
#   'Auh mihtoa in#aquinahquimamat',
#   'cahua, in#amo yolizmatqui, in amo',
#   'nenonotzale: in#ihcuacoquittac zan',
#   ', anozo cuitlatl ic con',
#   'tepachoa: auh amo#tle ic quicne',
#   'lia, zan no quitelchihua, itla neto',
#   'liniliztli ic quiteopoa, ic quimotla,',
#   'ic quihueyipoloa, azo huictli, mecapal',
#   'li quittitia. Auh in aquin, zan',
#   'huel mauhcatlacatl quimottitia: ni',
#   'man amo conyecoa, in#itemamauht',
#   'iliz: huel zotlahua, yolmiqui, ayocmo',
#   'chiche: huel icopac tlahuaqui, icamac',
#   ', icamac tlazazalia: ayo',
#   'cmo tlapalti, ayocmo tlapaltia in#i'],
#  24: ['ixpampa yehhua: ayocmo quihualittazn',
#   'equi, momauhcatlaloa: in#iuh moma',
#   'ti, ye omma aca ye quicuitihuetziz: in#o',
#   'quenteltzin acito ichan, motlaloti',
#   'calaqui, quipetlaticalaqui in#itla',
#   'tzacuil: tepan manenenticalaqui:',
#   'tepan mamazouhtihuetzi, in oncan',
#   'cochihua.',
#   'Ic matlactli omome capítulo;',
#   'mihtoa: in occentlamantli',
#   'tetzahuitl catca: in#itoca catca: tla',
#   'canexquimilli.',
#   'No ihuan, tetzahuitl catca, tete',
#   'tzahuiaya: in tlacanexquimilli, iuh',
#   'mihtoa: zan ye mochi yeh inahual,',
#   'inecuepaliz, inenextiliz in Tezcatli',
#   'poca: in#ihcuacittoya, zan momi',
#   'milotiuh, quiquinacatiuh, tehten',
#   'tiuh. In#aquin quittaya, ic#quite',
#   'tzanhuia, in ye miquiz: azo yaoc, anozo',
#   'zan tlalmiquiz: anoce itla, amo',
#   'cualli ye quimonamictiz, ipan hu',
#   'etziz. In#aquin amo yollochicahuac,',
#   'in amo yollatlapalihui, in zan mauh',
#   'catlacatl, intla#oquimottiti: zan ix'],
#  25: ['tonalcahualtia, quiicahuia: inic i',
#   'ciuhca miquiz, anozo intla amo',
#   'cualli quimonamictiz.Ç etc. Auh',
#   'in#aquin, huel yollotlapalihui: in mote',
#   'nehua: yaotlahueliloc, ic momania, ic',
#   'mochichihua, ic mocencahua: niman',
#   'iuh quimolhuia, in#yohualtica, nahua',
#   'ltetemoz, nohuiyan nehnemi: quitotoca',
#   'tinemi, in#izqui ochpantli, yohualn',
#   'enemi, quitetemotinemi, in azo cana',
#   'itla quimottitiz: inic quitlaniliz ite',
#   'nemac, iteicneliliz huitztli. Auh in',
#   'tla#ye#oquimottiti in#iuhqui in#y, quite',
#   'temoa: quicuitihuetzi, quiteteuhtzitz',
#   'quia, itech mopiloa: ayocmo quica',
#   'hua quitlatoltia, quilhuia: ac#tehhuatl in',
#   'nocne ?Ç xinechnotza, amo#mac',
#   'a titlahtoz: ca#onimitzan, amo ni',
#   'mitzcahuaz: huecauhtica quinemitia,',
#   'in quitlatoltia: ihcuac quinotza, qui',
#   'nanquilia intla#ye#caamana: in#ace',
#   'ipan tlahuiznequi, in ace quitlat',
#   'huiltia, quilhuia: xinechcahua ye',
#   'tinechitlacoa, tlein quinequi mo',
#   'yollo: nimitzmacaz, tlein tinech'],
#  26: ['ce huitztli: amo nicia, amo niccelia tle',
#   'nicchihuaz, ome, Ey, nahui quimaca: ca#za',
#   'nel amo ic quicahua: quinihcuac in#oqui',
#   'yolpachihuiti, in#oquiyolpachiuhcayoti',
#   'in ye quilhuia: mochi nimitzmaca in',
#   'necuiltonolli, titlamahuizoz in tlaltic',
#   'pac: ihcuac quicohua: ca#nel oconittac',
#   'in quitemoa iyollo, inic oelciciuhti',
#   'nenca, onentlamattinenca.Ç Etc.',
#   'Ic matlactli omeyi capítulo, on',
#   'can motenehua: in#occequi tetzahuitl,',
#   'in yohualtica monextiaya.',
#   'No ihuan, netetzahuiloya mo',
#   'teittitiaya: in#itoca cuitlapanton,',
#   'anozo cintanaton: mihtoa in#Acolhu',
#   'acan centlapachton: iuh tocayotilo.',
#   'Quihtoa, zan oncan in neaxixalo',
#   'yan, in tlazolpan moteittitiaya: in',
#   'tla#ye aca axixmiqui, in#zan#icel',
#   'yohualtica quiza: in#azo metztona, a',
#   'nozo tlayohua: ihcuac quimottitia:',
#   'zan yeh#moch ic quinextiaya in mi',
#   'quiztetzahuitl. In#aquin quimotti',
#   'tia, ic quitetzanhuia in#acemiquiz,'],
#  27: ['n#acanozo tlein, zan conmamauhtia:',
#   'auh inic ittoya, iuhquin cihuapiltontli,',
#   'zan huel tepiton, cihuapiltepiton: amo',
#   'achi cuauhtic: zan cacapanton, cha',
#   'chapaton, tzapaton, cuitlapachton,',
#   'tzonqueme, tzotzonqueme, tzotzoquen',
#   'pile: huel icuitlacaxiuhiyan huetzi, in#i',
#   'tzon, in#itzonquen: auh inic nehn',
#   'emi zan tlalli ixco onotiuh, pepe',
#   'yocatiuh, amo huel cana in quimott',
#   'itia: intla#ye#quitoca zan ixpan om',
#   'polihui, zan#ic#quiqueloa: ye#neh cecni,',
#   'in#hualmonextia: ompa quitoca in',
#   'canaznequi ompoliuhtiuh: zan',
#   'iuh commauhcacahua, conciauhca',
#   'hua, ommonenencoa.',
#   'Zan ye#no iuhqui in tzonteco',
#   'matl, no moteittitia in yohualtica:',
#   'in#aquinquimottitia, zan#ic qui',
#   'machitia, amo inemachpan',
#   'in#icotzco choloa: anoce icam',
#   'pa, concaqui chachalcatihuitz,',
#   'in#quihualtoca: ic ixpampa yehhua,',
#   'icampa chachalcatiuh in#quitoca.'],
#  28: ['no motlalia chachalcatinemi: auh',
#   'intla omoyollochichili, inic quicuit',
#   'ihuetziz: zan#ic quiqueloa, huehca ye',
#   'hhua in#choloa, amo#huel cana: zan',
#   'no iuh conmauhcacahua: ixpampa',
#   'yehhua: ixquich quitoctia, inic mo',
#   'mauhcatlaloa ichan.',
#   'Zan ye#no iuhqui in miqui, no',
#   'moteittitiaya: ihilpitica, cuacua',
#   'ilpitica, quiquinacatica: in cana',
#   'moteittitiaya: tequiquinatza: zan',
#   'yehhuan inyollo chicahuaque, huel ihuic',
#   'motlahpaloa in quicuitihuetzi: itech',
#   'mopiloca. Auh inic zan inca moca',
#   'cayahua, azo tlachcuitl, anozo tla',
#   'cuahuac tetl in#immac mocauhti',
#   'quiza: inic mocueptihuetzi: iuh mi',
#   'htoa, ca#zan mochi yeh, inahual in',
#   'Tezcatlipoca inic teca mocacayahuaya etc.',
#   'Tetzahuitl itechpa chiquimoli.',
#   'In#chiquimoli, ca#centetl tototl,',
#   'iuhquin cuauhchochopitli: auh huehca',
#   'cuauhtla in#ichan. Auh in#ihcuac',
#   'tepan tzatzia, netetzahuiloya: qui']}

# %%
import pickle

with open(f'ref_map_org2.pkl', 'wb') as pickle_file:
        pickle.dump(ref_map2,pickle_file)
        
with open(f'ref_map_norm2.pkl', 'wb') as pickle_file:
        pickle.dump(norm_map2,pickle_file)

# %%
"""
temp_ref = {}
punct = ['.',':',',','?']
others = ['·','¶']
for k in range(3,30):
    temp_ref[k] = ""
    
    for sent in ref_map[k]:
        x = sent
        
        for p in punct:
            x = x.replace(p, others[0]+p)
        
        x = x.replace(" ",others[0])
        
        x = x+others[1]
        x = x.replace("\n","")
        temp_ref[k]+=x
"""
num_line_data = {}

import pickle
with open(f'ref_map.pkl', 'rb') as pickle_file:
        ref_map = pickle.load(pickle_file)

for k in range(3,30):
    to_remove = []

    for ele in ref_map[k]:
        
        if len(ele.strip()) == 0:
            to_remove.append(ele)
            
    for t in to_remove:
        ref_map[k].remove(t)
    
    
        

characters_list = ["(" + str(i) + ")" for i in range(1, 51)]

for k in range(3,30):
    for i in range(len(ref_map[k])):
        for c in characters_list:
            ref_map[k][i] = ref_map[k][i].replace(c,'')
            

for k in range(3,30):
    for cnt in range(len(ref_map[k])):
        ref_map[k][cnt] = ref_map[k][cnt].replace('Ã§','ç')
        ref_map[k][cnt] = ref_map[k][cnt].replace('Â§','Ç')

for k in range(3,30):
    n = len(ref_map[k])
    num_line_data[k] = n

from conllu import parse

with open(file_path, "r", encoding="utf-8") as f:
    data = f.read()

# Parse the CoNLL-U data
parsed_data = parse(data)

all_orig_text = ""


punct = ['.',':',',',';','?']
others = ['·','¶']
for k in range(3,30):
    
    for sent in ref_map[k]:
        x = sent
        
        for p in punct:
            x = x.replace(p, others[0]+p)
        
        x = x.replace(" ",others[0])
        
        x = x+others[1]
        x = x.replace("\n","")
        all_orig_text+=x
    
all_orig_text = all_orig_text.strip()


for key in org_to_norm.keys():
    k = key
    
    if "¶·" in key:
        k = k.replace("¶·","¶")
    
    if "·" in k and "¶·" not in k:
        k = k.replace("·","#")
        
    
    all_orig_text.replace(key,k)


for key in org_to_norm_final.keys():
    k = key
    if "#" in k:
        k = k.replace("#","·")
        
        if k in all_orig_text:
            all_orig_text = all_orig_text.replace(k,key)

import re     


all_orig_text = all_orig_text.replace(".¶",".¶·")
all_orig_text = all_orig_text.replace(",¶",",¶·")
all_orig_text = all_orig_text.replace(":¶",":¶·")
all_orig_text = all_orig_text.replace("·¶","·¶·")
all_orig_text = re.sub(r'\·+', '·', all_orig_text)

# %%
org_to_norm_final["¶"] = "¶"
org_to_norm_final[".¶"] = ".¶"
org_to_norm_final[":¶"] = ":¶"
org_to_norm_final[",¶"] = ",¶"
org_to_norm_final["?Ç"] = "?Ç"
org_to_norm_final["&c"] = "etc"
org_to_norm_final[".Ç"] = ".Ç"
org_to_norm_final["etc"] = "etc"
org_to_norm_final["Etc"] = "Etc"
org_to_norm_final["tecoloo"] = "tecoloo"
org_to_norm_final["tetza"] = "tetza"
org_to_norm_final["vitl"] = "huitl"
org_to_norm_final["espaÃ±a"] = "España"
org_to_norm_final["inte"] = "in"
org_to_norm_final["mj#qujztemachi¶que"] = "temiquiztemachi¶ani"
org_to_norm_final["temj#qujz"] = "temiquiz"


orig_tokens = all_orig_text.split("·")

norm_tokens = []

for token in orig_tokens:
    if token in org_to_norm_final:
        norm_tokens.append(org_to_norm_final[token])
        
    else:
        
        print(token)
        if "," in token:
            norm_tokens.append(token[0]+org_to_norm_final[token[1:]])


        elif "¶" in token:
            split_token = token.split("¶")
            cnt = 0
            n = len(split_token)
            for s in split_token:
                if cnt<n-1:
                    if len(s)>0:
                        norm_tokens.append(org_to_norm_final[s]+"¶")
                cnt+=1

        elif "¶" not in token:
            if "#" in token:
                split_token = token.split("#")

                for s in split_token:
                    if len(s)>0:
                        norm_tokens.append(org_to_norm_final[s])

# %%
norm_tokens

# %%
norm_text = ""

for token in norm_tokens:
    if token[0] in punct or token[0] in others:
        norm_text+=token
        
    else:
        norm_text+=" "+token

# %%
norm_text = norm_text.strip()
norm_text = norm_text.replace(others[0]," ")
norm_text = re.sub(r'\¶+', '¶', norm_text)
norm_text = norm_text.replace("¶c¶","c¶")
norm_text = norm_text.replace("In#ihcu¶ac¶","In#ihcuac¶")
#In#ihcu¶ac¶

all_orig_text = all_orig_text.strip()
all_orig_text = all_orig_text.replace(others[0]," ")
all_orig_text = re.sub(r'\¶+', '¶', all_orig_text)
all_orig_text = all_orig_text.replace("¶c¶","c¶")

# %%
#ref_map_org[28]

# %%
norm_sentences = norm_text.split("¶")

list1 = all_orig_text.split("¶")
list2 = norm_text.split("¶")

for i in range(len(list1)):
    list1[i] = list1[i].strip()
    for p in punct:
        if p !="?":
            list1[i] = list1[i].replace(" "+p,p)
        elif p == "?":
            list1[i] = list1[i].replace(p," "+p)
    
for i in range(len(list2)):
    list2[i] = list2[i].strip()

# %%
list2.remove("ac")
list2[89] = list2[89] + list2[90]
list2.remove(list2[90])
list2[130] = list2[130] + list2[131]
list2.remove(list2[131])
list2[139] = "caiac " + list2[139]
list2[148] = "njcan " + list2[139]
list2[152] = list2[152] + list2[153]
list2.remove(list2[153])
list2[176] = "in#inteouh "
list2[176] = list2[176] + list2[177]
list2.remove(list2[177])
list2[197] = list2[197] + list2[198]
list2.remove(list2[198])
list2[233] = "quimatia "+list2[233]
list2[259] = list2[259] + list2[260]
list2.remove(list2[260])
list2[261] = list2[261].replace("in", " in")
list2[274] = list2[274] + list2[275]
list2.remove(list2[275])
list2[291] = list2[291] + list2[292]
list2.remove(list2[292])
list2[307] = list2[308]
list2.remove(list2[308])
list2[323] = list2[323] + list2[324]
list2.remove(list2[324])
list2[326] = list2[326] + list2[327]
list2.remove(list2[327])
list2[333] = list2[333] + list2[334]
list2.remove(list2[334])
list2[380] = list2[380] + list2[381]
list2.remove(list2[381])
list2[407] = list2[407] + list2[408]
list2.remove(list2[408])
list2[419] = "ichan" + list2[419]
list2[421] = list2[421] + list2[422]
list2[422] = list2[423]
list2.pop(423)
list2[440] = list2[440] + list2[441]
list2.pop(441)
list2[474] = list2[474] + list2[475]
list2.pop(475)
list2[469] = "no#mihtoa" + list2[469]
list2[475] = list2[475] + list2[476]
list2.pop(476)
list2[476] = list2[476] + " " + list2[477]
list2.pop(477)
list2[479] = list2[479] + list2[480]
list2.pop(480)
list2[486] = list2[486] + list2[487]
list2.pop(487)
list2[489] = list2[489] + list2[490]
list2.pop(490)
list2[501] = list2[501] + list2[502]
list2.pop(502)
list2[505] = list2[505] + list2[506]
list2.pop(506)
list2[524] = "teveijecoanj " + list2[524]
list2[549] = list2[549] + list2[550]
list2.pop(550)
list2[555] = list2[555] + list2[556]
list2.pop(556)
list2[563] = list2[563] + list2[564]
list2.pop(564)
list2[565] = list2[565] + list2[566]
list2.pop(566)
list2[595] = list2[595] + list2[596]
list2.pop(596)
list2[608] = list2[608] + list2[609]
list2.pop(609)
list2[621] = "nocne " + list2[621]
list2[654] = list2[654] + list2[655]
list2.pop(655)
list2[674] = list2[674] + list2[675]
list2.pop(675)
list2[703] = list2[703] + list2[704]
list2[704] = "tepan tzatzia, netetzahuiloya: qui"

# %%
ref_map_org = {}
ref_map_norm = {}

start = 0
end = paragraph_data["3"][-1][-1]+1

cnt = 0
for k in range(3,29):
    
    x = list1[start:end]
    y = list2[start:end]
    
    if k == 4:
        y[-5] = "injn" + y[-5]
    
    elif k == 5:
        y[0] = "ocnen " + y[0]
        #y[-3] = y[-3] + y[-2]
        #y.remove(y[-2])
        
    print(k)
    print()
    for i in range(len(x)):
        print(f"{cnt} {x[i]} | {y[i]}")
        cnt+=1
    print()
    
    
   
    ref_map_org[k] = x
    ref_map_norm[k] = y
    
    
    if k!=28:
        start = end 
        end = start + paragraph_data[str(k+1)][-1][-1]+1

# %%
#523
len(list1), len(list2)

# %%
import pickle
with open("ref_map_org.pkl", 'wb') as file1:
    # Serialize and write the data to the file
    pickle.dump(ref_map_org, file1)

with open("ref_map_norm.pkl", 'wb') as file2:
    # Serialize and write the data to the file
    pickle.dump(ref_map_norm, file2)

# %%
x = ref_map_org
y = ref_map_norm

for k in range(3,29):
    print(f"{k} {len(x[k])} {len(y[k])}")

# %%
list1 = all_orig_text.split("¶")
list2 = all_norm_text.split("¶")
print(len(list1))
print(len(list2))

check_sum = 0
for k in num_line_data:
    check_sum+=num_line_data[k]
print(check_sum)
new_punct = ['·.','·:','·,','·?']
punct = ['.',':',',','?']
orig = {}
norm = {}
for k in range(3,30):
    orig[k] = []
    norm[k] = []
    
start = 0
for k in num_line_data:
    n = num_line_data[k]
    end = start + n
    for idx in range(start,end):
        for j in range(len(new_punct)):
            list1[idx] = list1[idx].replace(new_punct[j],punct[j])
            list2[idx] = list2[idx].replace(new_punct[j],punct[j])
        list1[idx] = list1[idx].replace('·',' ')
        list2[idx] = list2[idx].replace('·',' ')
        
        orig[k].append(list1[idx])
        norm[k].append(list2[idx])
    
    start = end

# %%
for i in range(29):
    print(list1[i])
    print(ref_map[3][i])
    print()

# %%
import pickle
with open(f'ref_map.pkl', 'rb') as pickle_file:
        ref_map = pickle.load(pickle_file)
        
with open(f'norm_ref_map.pkl', 'rb') as pickle_file:
        norm_ref_map = pickle.load(pickle_file)
        


for k in range(3,29):
    to_remove = []

    for ele in ref_map[k]:
        
        if len(ele.strip()) == 0:
            to_remove.append(ele)
            
    for t in to_remove:
        ref_map[k].remove(t)
    
    
        

characters_list = ["(" + str(i) + ")" for i in range(1, 51)]

for k in range(3,29):
    for i in range(len(ref_map[k])):
        for c in characters_list:
            ref_map[k][i] = ref_map[k][i].replace(c,'')
            

for k in range(3,29):
    for cnt in range(len(ref_map[k])):
        ref_map[k][cnt] = ref_map[k][cnt].replace('Ã§','ç')
        ref_map[k][cnt] = ref_map[k][cnt].replace('Â§','Ç')
        
        norm_ref_map[k][cnt] = norm_ref_map[k][cnt].replace('Ã§','ç')
        norm_ref_map[k][cnt] = norm_ref_map[k][cnt].replace('Â§','Ç')

# %%
temp_ref = {}
punct = ['.',':',',','?']
others = ['·','¶']
for k in range(3,30):
    temp_ref[k] = ""
    
    for sent in ref_map[k]:
        x = sent
        
        for p in punct:
            x = x.replace(p, others[0]+p)
        
        x = x.replace(" ",others[0])
        
        x = x+others[1]
        x = x.replace("\n","")
        temp_ref[k]+=x

# %%
temp_ref

# %%
keys = org_to_norm.keys()
for k in range(3,30):
    str_ = temp_ref[k]
    
    for key in keys:
        if "·" in key and key in str_:
            word = key
            new_word = key.replace("·","#")
            str_ = str_.replace(word,new_word)
            temp_ref[k] = str_

# %%
"""
for k in range(3,30):
    temp_ref[k] = temp_ref[k].replace(".¶",".¶·")
    temp_ref[k] = temp_ref[k].replace("·¶","¶")
    temp_ref[k] = temp_ref[k].replace(",¶",",¶·")
    temp_ref[k] = temp_ref[k].replace(":¶",":¶·")
"""



    
temp_ref

# %%
ref_map_org = {}
ref_map_org_list = {}
punct = ['.',':',',','?']
for k in range(3,30):
    str_ = temp_ref[k]
    new_str = ""
    for c in str_:
        
        if c in punct:
            new_str = new_str[:-1]
            new_str+=c
        else:
            new_str+=c
            
        
        
    list_ = str_.split("·")
    ref_map_org_list[k] = list_
    
    new_str = new_str.replace("·"," ")
    list2 = new_str.split("¶")
    
    for i in range(len(list2)):
        list2[i] = list2[i].strip()
    
    ref_map_org[k] = list2[:-1]
    
    
    
ref_map_org_list

# %%
org_to_norm

# %%
ref_map_norm = {}

for k in range(3,30):
    curr = ref_map_org_list[k]
    
    str_= ""
    for c in curr:
        if len(c)>0:
            if c[-1] == "¶":
                str_+=c
                if len(c)>1:
                    str_ = str_[:-1]
                str_+="\n"
            elif c in punct:
                str_+=c

            else:
                str_+=" "+org_to_norm_final[c]
    ref_map_norm[k] = str_.split("\n")
    
ref_map_norm

# %%
ref_map_norm = {}
for k in range(3,30):
    x = new_temp_ref[k]
    nx = ""
    for c in x:
        if c in punct:
            nx = nx[:-1]
            nx+=c
            
        else:
            nx+=c
    
    nx = nx.replace("·"," ")
    
    list_ = nx.split("¶")
    
    ref_map_norm[k] = list_[:-1]
    
ref_map_norm

# %%
import pickle
with open('ref_map_norm.pkl', "wb") as pickle_file:
    pickle.dump(ref_map_norm,pickle_file)

# %%
keys = org_to_norm.keys()
for k in range(3,30):
    str_ = temp_ref[k]
    
    for key in keys:
        if "·" in key and key in str_:
            word = key
            new_word = key.replace("·","#")
            str_ = str_.replace(word,new_word)
            temp_ref[k] = str_

# %%
ref_map_org = {}
for k in range(3,30):
    x = temp_ref[k]
    nx = ""
    for c in x:
        if c in punct:
            nx = nx[:-1]
            nx+=c
            
        else:
            nx+=c
    
    nx = nx.replace("·"," ")
    
    list_ = nx.split("¶")
    
    ref_map_org[k] = list_[:-1]
    
ref_map_org

# %%
import pickle
with open('ref_map_org.pkl', "wb") as pickle_file:
    pickle.dump(ref_map_org,pickle_file)

# %%
punct = ['.',':',',','?']
others = ['·','¶']

for i in range(len(orig_text)):
    temp = []
    temp_str = ''
    for j in range(len(orig_text[i])):
        temp.append(orig_text[i][j])
        
    for k in range(len(temp)):
        if temp[k] != others[0]:
            temp_str+=temp[k]
        
        else:
            if temp[k] == others[0]:
                if temp[k+1] in punct:
                    temp_str+=""
                    
                else:
                    temp_str+=" "
    
        orig_text[i] = temp_str
    
orig_text

# %%
print(orig_text[0])
print(norm_text[0])

# %%
pipe1 = []
for i in range(len(orig_text)):
    orig = orig_text[i]
    norm = norm_text[i]
    
    t1 = orig.split()
    t2 = norm.split()
    
    t3 = []
    t4 = []
    cnt = 0
    print('Orig: ',orig)
    print('Norm: ',norm)
    print()
    
    for j in range(len(t1)):
        if len(t2[cnt])<0.3*len(t1[j]):
            t3.append(t2[cnt]+"|"+t2[cnt+1])
            cnt+=1
            
        else:
            t3.append(t2[cnt])

        print(t1[:j+1])   
        print(t3)
        print()
        cnt+=1
    pipe1.append(" ".join(t3))

# %%
print(pipe1[0])
print(orig_text[0])

# %%
x = 'abcd'

print('ab' in x)
